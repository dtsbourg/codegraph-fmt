# %% [markdown]
# # Experiment Template
#
# Duplicate this notebook to have all you need to kickstart a new experiment.

# %%
# Import numpy

import numpy as np

# %%
# Import from system
import os
import json
import random

# %%
# Import scikit-learn (mainly for train/test splits)
import sklearn
from sklearn.metrics import roc_auc_score, precision_recall_curve, average_precision_score
from sklearn.utils.fixes import signature
from sklearn.preprocessing import LabelBinarizer

# %%
# Import graph framework
import networkx as nx
from networkx.readwrite import json_graph

# %%
# Import and configure plotting library
import matplotlib.pyplot as plt
# %matplotlib inline

step_kwargs = ({'step': 'post'}
               if 'step' in signature(plt.fill_between).parameters
               else {})

# %% [markdown]
# ## Configuration

# %%
# Define paths to data and models
DATA_PATH = 'data/keras-example/graph/train/'
PREFIX = 'keras'

# %% [markdown]
# ## Load data

# %%
var_map = json.load(open(DATA_PATH+PREFIX+"-var_map.json"))

# %%
def fix_encoding(d):
    enc_d = {}
    for k,v in d.items():
        enc_k = k.encode("utf-8")
        enc_v = v.encode("utf-8")
        enc_d[enc_k] = enc_v
    return enc_d

# %%
var_map
# Out:
# {'39': 'h5py',
#  '43': 'model',
#  '44': 'input_tensors',
#  '71': 'layer_map',
#  '74': 'tensor_map',
#  '82': 'input_layers',
#  '85': 'input_tensors',
#  '88': 'layer',
#  '89': '_input_layers',
#  '92': 'input_tensor',
#  '96': 'batch_input_shape',
#  '99': 'dtype',
#  '102': 'sparse',
#  '105': 'name',
#  '109': 'append',
#  '113': 'newly_created_input_layer',
#  '115': '_keras_history',
#  '127': '_original',
#  '128': '_cloned',
#  '131': '_input_layers',
#  '141': 'input_tensors',
#  '146': '_input_tensors',
#  '150': 'i',
#  '151': 'x',
#  '158': 'is_keras_tensor',
#  '162': 'name',
#  '163': 'name',
#  '165': '_input_layers',
#  '170': 'input_tensor',
#  '182': 'append',
#  '186': 'original_input_layer',
#  '188': '_keras_history',
#  '193': 'newly_created_input_layer',
#  '195': '_keras_history',
#  '207': 'append',
#  '211': 'input_tensors',
#  '215': 'x',
#  '216': 'y',
#  '219': 'inputs',
#  '231': 'depth_keys',
#  '235': 'keys',
#  '236': '_nodes_by_depth',
#  '240': 'sort',
#  '245': 'depth',
#  '248': 'nodes',
#  '250': '_nodes_by_depth',
#  '255': 'node',
#  '258': 'layer',
#  '259': 'outbound_layer',
#  '267': 'new_layer',
#  '269': 'from_config',
#  '270': '__class__',
#  '273': 'get_config',
#  '282': 'layer',
#  '285': 'layer',
#  '297': 'reference_input_tensors',
#  '298': 'input_tensors',
#  '301': 'reference_output_tensors',
#  '302': 'output_tensors',
#  '305': 'computed_data',
#  '308': 'x',
#  '317': 'append',
#  '333': 'arguments',
#  '336': 'kwargs',
#  '337': 'arguments',
#  '340': 'kwargs',
#  '350': 'computed_tensor',
#  '351': 'computed_mask',
#  '359': 'call',
#  '373': 'output_tensors',
#  '382': 'output_masks',
#  '386': 'compute_mask',
#  '391': 'computed_tensors',
#  '395': 'computed_masks',
#  '399': 'computed_tensors',
#  '406': 'x',
#  '409': 'computed_masks',
#  '416': 'x',
#  '421': 'call',
#  '435': 'output_tensors',
#  '444': 'output_masks',
#  '448': 'compute_mask',
#  '454': 'x',
#  '455': 'y',
#  '456': 'mask',
#  '471': 'output_tensors',
#  '474': 'x',
#  '475': 'outputs',
#  '488': 'tensor',
#  '489': '_',
#  '496': 'append',
#  '505': 'name',
#  '509': 'model',
#  '510': 'input_tensors',
#  '527': 'layer',
#  '530': 'from_config',
#  '531': '__class__',
#  '534': 'get_config',
#  '537': 'layers',
#  '543': 'layer',
#  '544': 'layers',
#  '556': 'name',
#  '572': 'x',
#  '581': 'is_keras_tensor',
#  '585': 'origin_layer',
#  '587': '_keras_history',
#  '605': 'name',
#  '612': 'input_tensor',
#  '622': 'name',
#  '625': 'input_layer',
#  '627': '_keras_history',
#  '640': 'name',
#  '644': 'model',
#  '645': 'input_tensors',
#  '687': 'x',
#  '688': 'axis',
#  '695': 'ndim',
#  '697': 'ndim',
#  '715': 'softmax',
#  '724': 'e',
#  '726': 'exp',
#  '732': 'max',
#  '740': 's',
#  '742': 'sum',
#  '763': 'x',
#  '764': 'alpha',
#  '770': 'elu',
#  '776': 'x',
#  '780': 'alpha',
#  '783': 'scale',
#  '790': 'elu',
#  '796': 'x',
#  '801': 'softplus',
#  '806': 'x',
#  '811': 'softsign',
#  '816': 'x',
#  '817': 'alpha',
#  '818': 'max_value',
#  '819': 'threshold',
#  '827': 'relu',
#  '838': 'x',
#  '843': 'tanh',
#  '848': 'x',
#  '853': 'sigmoid',
#  '858': 'x',
#  '863': 'hard_sigmoid',
#  '868': 'x',
#  '873': 'exp',
#  '878': 'x',
#  '885': 'activation',
#  '887': '__name__',
#  '891': 'name',
#  '892': 'custom_objects',
#  '907': 'identifier',
#  '921': 'string_types',
#  '924': 'identifier',
#  '943': 'warn',
#  '946': 'format',
#  '949': '__name__',
#  '950': '__class__',
#  '1004': 'y_true',
#  '1005': 'y_pred',
#  '1008': 'mean',
#  '1011': 'equal',
#  '1015': 'round',
#  '1024': 'y_true',
#  '1025': 'y_pred',
#  '1028': 'cast',
#  '1031': 'equal',
#  '1034': 'argmax',
#  '1041': 'argmax',
#  '1048': 'floatx',
#  '1052': 'y_true',
#  '1053': 'y_pred',
#  '1056': 'cast',
#  '1059': 'equal',
#  '1062': 'flatten',
#  '1066': 'cast',
#  '1069': 'argmax',
#  '1076': 'floatx',
#  '1079': 'floatx',
#  '1083': 'y_true',
#  '1084': 'y_pred',
#  '1085': 'k',
#  '1089': 'mean',
#  '1092': 'in_top_k',
#  '1096': 'argmax',
#  '1108': 'y_true',
#  '1109': 'y_pred',
#  '1110': 'k',
#  '1114': 'mean',
#  '1117': 'in_top_k',
#  '1121': 'cast',
#  '1124': 'flatten',
#  '1133': 'mse',
#  '1134': 'MSE',
#  '1137': 'mae',
#  '1138': 'MAE',
#  '1141': 'mape',
#  '1142': 'MAPE',
#  '1145': 'msle',
#  '1146': 'MSLE',
#  '1149': 'cosine',
#  '1153': 'metric',
#  '1160': 'config',
#  '1161': 'custom_objects',
#  '1176': 'identifier',
#  '1183': 'config',
#  '1199': 'string_types',
#  '1263': 'requests',
#  '1271': 'self',
#  '1272': 'callbacks',
#  '1273': 'queue_length',
#  '1277': 'callbacks',
#  '1283': 'callbacks',
#  '1288': 'c',
#  '1291': 'queue_length',
#  '1296': 'self',
#  '1297': 'callback',
#  '1300': 'append',
#  '1301': 'callbacks',
#  '1306': 'self',
#  '1307': 'params',
#  '1309': 'callback',
#  '1310': 'callbacks',
#  '1314': 'set_params',
#  '1319': 'self',
#  '1320': 'model',
#  '1322': 'callback',
#  '1323': 'callbacks',
#  '1327': 'set_model',
#  '1332': 'self',
#  '1333': 'epoch',
#  '1334': 'logs',
#  '1339': 'logs',
#  '1344': 'callback',
#  '1345': 'callbacks',
#  '1349': 'on_epoch_begin',
#  '1354': '_delta_t_batch',
#  '1358': '_delta_ts_batch_begin',
#  '1364': 'queue_length',
#  '1367': '_delta_ts_batch_end',
#  '1373': 'queue_length',
#  '1377': 'self',
#  '1378': 'epoch',
#  '1379': 'logs',
#  '1384': 'logs',
#  '1389': 'callback',
#  '1390': 'callbacks',
#  '1394': 'on_epoch_end',
#  '1400': 'self',
#  '1401': 'batch',
#  '1402': 'logs',
#  '1407': 'logs',
#  '1412': 't_before_callbacks',
#  '1414': 'time',
#  '1417': 'callback',
#  '1418': 'callbacks',
#  '1422': 'on_batch_begin',
#  '1428': 'append',
#  '1429': '_delta_ts_batch_begin',
#  '1433': 'time',
#  '1438': 'delta_t_median',
#  '1440': 'median',
#  '1442': '_delta_ts_batch_begin',
#  '1448': '_delta_t_batch',
#  '1457': '_delta_t_batch',
#  '1464': 'warn',
#  '1471': '_t_enter_batch',
#  '1474': 'time',
#  '1478': 'self',
#  '1479': 'batch',
#  '1480': 'logs',
#  '1485': 'logs',
#  '1497': '_t_enter_batch',
#  '1500': 'time',
#  '1503': '_delta_t_batch',
#  '1507': 'time',
#  '1509': '_t_enter_batch',
#  '1512': 't_before_callbacks',
#  '1514': 'time',
#  '1517': 'callback',
#  '1518': 'callbacks',
#  '1522': 'on_batch_end',
#  '1528': 'append',
#  '1529': '_delta_ts_batch_end',
#  '1533': 'time',
#  '1537': 'delta_t_median',
#  '1539': 'median',
#  '1541': '_delta_ts_batch_end',
#  '1546': '_delta_t_batch',
#  '1554': '_delta_t_batch',
#  '1561': 'warn',
#  '1568': 'self',
#  '1569': 'logs',
#  '1574': 'logs',
#  '1579': 'callback',
#  '1580': 'callbacks',
#  '1584': 'on_train_begin',
#  '1589': 'self',
#  '1590': 'logs',
#  '1595': 'logs',
#  '1600': 'callback',
#  '1601': 'callbacks',
#  '1605': 'on_train_end',
#  '1610': 'self',
#  '1614': 'callbacks',
#  '1622': 'self',
#  '1624': 'validation_data',
#  '1628': 'model',
#  '1633': 'self',
#  '1634': 'params',
#  '1636': 'params',
#  '1641': 'self',
#  '1642': 'model',
#  '1644': 'model',
#  '1649': 'self',
#  '1650': 'epoch',
#  '1651': 'logs',
#  '1656': 'self',
#  '1657': 'epoch',
#  '1658': 'logs',
#  '1663': 'self',
#  '1664': 'batch',
#  '1665': 'logs',
#  '1670': 'self',
#  '1671': 'batch',
#  '1672': 'logs',
#  '1677': 'self',
#  '1678': 'logs',
#  '1683': 'self',
#  '1684': 'logs',
#  '1693': 'self',
#  '1694': 'stateful_metrics',
#  '1699': 'stateful_metrics',
#  '1705': 'stateful_metrics',
#  '1711': 'self',
#  '1712': 'epoch',
#  '1713': 'logs',
#  '1716': 'seen',
#  '1720': 'totals',
#  '1725': 'self',
#  '1726': 'batch',
#  '1727': 'logs',
#  '1730': 'logs',
#  '1735': 'batch_size',
#  '1737': 'get',
#  '1742': 'seen',
#  '1748': 'k',
#  '1749': 'v',
#  '1751': 'items',
#  '1757': 'stateful_metrics',
#  '1761': 'totals',
#  '1769': 'totals',
#  '1773': 'totals',
#  '1782': 'totals',
#  '1791': 'self',
#  '1792': 'epoch',
#  '1793': 'logs',
#  '1801': 'k',
#  '1803': 'params',
#  '1810': 'totals',
#  '1815': 'stateful_metrics',
#  '1823': 'totals',
#  '1834': 'totals',
#  '1839': 'seen',
#  '1847': 'self',
#  '1848': 'batch',
#  '1849': 'logs',
#  '1852': 'logs',
#  '1857': 'loss',
#  '1859': 'get',
#  '1869': 'isnan',
#  '1873': 'isinf',
#  '1883': 'stop_training',
#  '1884': 'model',
#  '1893': 'self',
#  '1894': 'count_mode',
#  '1895': 'stateful_metrics',
#  '1900': '__init__',
#  '1911': 'use_steps',
#  '1919': 'use_steps',
#  '1933': 'stateful_metrics',
#  '1939': 'stateful_metrics',
#  '1945': 'self',
#  '1946': 'logs',
#  '1949': 'verbose',
#  '1952': 'params',
#  '1957': 'epochs',
#  '1960': 'params',
#  '1966': 'self',
#  '1967': 'epoch',
#  '1968': 'logs',
#  '1971': 'verbose',
#  '1982': 'epochs',
#  '1985': 'use_steps',
#  '1988': 'target',
#  '1990': 'params',
#  '1995': 'target',
#  '1997': 'params',
#  '2002': 'target',
#  '2006': 'progbar',
#  '2011': 'target',
#  '2014': 'verbose',
#  '2017': 'stateful_metrics',
#  '2020': 'seen',
#  '2025': 'self',
#  '2026': 'batch',
#  '2027': 'logs',
#  '2031': 'seen',
#  '2034': 'target',
#  '2037': 'log_values',
#  '2042': 'self',
#  '2043': 'batch',
#  '2044': 'logs',
#  '2047': 'logs',
#  '2052': 'batch_size',
#  '2054': 'get',
#  '2059': 'use_steps',
#  '2062': 'seen',
#  '2066': 'seen',
#  '2070': 'k',
#  '2072': 'params',
#  '2082': 'append',
#  '2083': 'log_values',
#  '2093': 'verbose',
#  '2096': 'seen',
#  '2098': 'target',
#  '2102': 'update',
#  '2103': 'progbar',
#  '2105': 'seen',
#  '2107': 'log_values',
#  '2111': 'self',
#  '2112': 'epoch',
#  '2113': 'logs',
#  '2116': 'logs',
#  '2121': 'k',
#  '2123': 'params',
#  '2133': 'append',
#  '2134': 'log_values',
#  '2143': 'verbose',
#  '2147': 'update',
#  '2148': 'progbar',
#  '2150': 'seen',
#  '2152': 'log_values',
#  '2160': 'self',
#  '2161': 'logs',
#  '2164': 'epoch',
#  '2168': 'history',
#  '2173': 'self',
#  '2174': 'epoch',
#  '2175': 'logs',
#  '2178': 'logs',
#  '2184': 'append',
#  '2185': 'epoch',
#  '2190': 'k',
#  '2191': 'v',
#  '2193': 'items',
#  '2197': 'append',
#  '2199': 'setdefault',
#  '2200': 'history',
#  '2211': 'self',
#  '2212': 'filepath',
#  '2213': 'monitor',
#  '2214': 'verbose',
#  '2215': 'save_best_only',
#  '2216': 'save_weights_only',
#  '2217': 'mode',
#  '2218': 'period',
#  '2227': '__init__',
#  '2233': 'monitor',
#  '2237': 'verbose',
#  '2241': 'filepath',
#  '2245': 'save_best_only',
#  '2249': 'save_weights_only',
#  '2253': 'period',
#  '2257': 'epochs_since_last_save',
#  '2270': 'warn',
#  '2277': 'mode',
#  '2284': 'monitor_op',
#  '2286': 'less',
#  '2289': 'best',
#  '2291': 'Inf',
#  '2298': 'monitor_op',
#  '2300': 'greater',
#  '2303': 'best',
#  '2307': 'Inf',
#  '2313': 'monitor',
#  '2316': 'startswith',
#  '2317': 'monitor',
#  '2321': 'monitor_op',
#  '2323': 'greater',
#  '2326': 'best',
#  '2329': 'Inf',
#  '2332': 'monitor_op',
#  '2334': 'less',
#  '2337': 'best',
#  '2339': 'Inf',
#  '2343': 'self',
#  '2344': 'epoch',
#  '2345': 'logs',
#  '2348': 'logs',
#  '2353': 'epochs_since_last_save',
#  '2358': 'epochs_since_last_save',
#  '2361': 'period',
#  '2364': 'epochs_since_last_save',
#  '2368': 'filepath',
#  '2370': 'format',
#  '2371': 'filepath',
#  '2380': 'save_best_only',
#  '2383': 'current',
#  '2385': 'get',
#  '2387': 'monitor',
#  '2396': 'warn',
#  '2400': 'monitor',
#  '2405': 'monitor_op',
#  '2408': 'best',
#  '2412': 'verbose',
#  '2424': 'monitor',
#  '2426': 'best',
#  '2431': 'best',
#  '2435': 'save_weights_only',
#  '2439': 'save_weights',
#  '2440': 'model',
#  '2447': 'save',
#  '2448': 'model',
#  '2455': 'verbose',
#  '2467': 'monitor',
#  '2469': 'best',
#  '2473': 'verbose',
#  '2487': 'save_weights_only',
#  '2491': 'save_weights',
#  '2492': 'model',
#  '2499': 'save',
#  '2500': 'model',
#  '2511': 'self',
#  '2512': 'monitor',
#  '2513': 'min_delta',
#  '2514': 'patience',
#  '2515': 'verbose',
#  '2516': 'mode',
#  '2517': 'baseline',
#  '2518': 'restore_best_weights',
#  '2528': '__init__',
#  '2534': 'monitor',
#  '2538': 'baseline',
#  '2542': 'patience',
#  '2546': 'verbose',
#  '2550': 'min_delta',
#  '2554': 'wait',
#  '2558': 'stopped_epoch',
#  '2562': 'restore_best_weights',
#  '2566': 'best_weights',
#  '2578': 'warn',
#  '2585': 'mode',
#  '2592': 'monitor_op',
#  '2594': 'less',
#  '2601': 'monitor_op',
#  '2603': 'greater',
#  '2608': 'monitor',
#  '2611': 'monitor_op',
#  '2613': 'greater',
#  '2616': 'monitor_op',
#  '2618': 'less',
#  '2622': 'monitor_op',
#  '2624': 'greater',
#  '2627': 'min_delta',
#  '2631': 'min_delta',
#  '2637': 'self',
#  '2638': 'logs',
#  '2641': 'wait',
#  '2645': 'stopped_epoch',
#  '2650': 'baseline',
#  '2654': 'best',
#  '2656': 'baseline',
#  '2659': 'best',
#  '2663': 'monitor_op',
#  '2665': 'less',
#  '2667': 'Inf',
#  '2670': 'Inf',
#  '2674': 'self',
#  '2675': 'epoch',
#  '2676': 'logs',
#  '2679': 'current',
#  '2681': 'get_monitor_value',
#  '2691': 'monitor_op',
#  '2695': 'min_delta',
#  '2697': 'best',
#  '2700': 'best',
#  '2704': 'wait',
#  '2708': 'restore_best_weights',
#  '2711': 'best_weights',
#  '2714': 'get_weights',
#  '2715': 'model',
#  '2718': 'wait',
#  '2723': 'wait',
#  '2725': 'patience',
#  '2728': 'stopped_epoch',
#  '2732': 'stop_training',
#  '2733': 'model',
#  '2737': 'restore_best_weights',
#  '2741': 'verbose',
#  '2750': 'set_weights',
#  '2751': 'model',
#  '2753': 'best_weights',
#  '2757': 'self',
#  '2758': 'logs',
#  '2763': 'stopped_epoch',
#  '2767': 'verbose',
#  '2776': 'stopped_epoch',
#  '2781': 'self',
#  '2782': 'logs',
#  '2784': 'monitor_value',
#  '2786': 'get',
#  '2788': 'monitor',
#  '2796': 'warn',
#  '2801': 'monitor',
#  '2804': 'join',
#  '2809': 'keys',
#  '2820': 'self',
#  '2821': 'root',
#  '2822': 'path',
#  '2823': 'field',
#  '2824': 'headers',
#  '2825': 'send_as_json',
#  '2833': '__init__',
#  '2839': 'root',
#  '2843': 'path',
#  '2847': 'field',
#  '2851': 'headers',
#  '2855': 'send_as_json',
#  '2860': 'self',
#  '2861': 'epoch',
#  '2862': 'logs',
#  '2873': 'logs',
#  '2878': 'send',
#  '2888': 'k',
#  '2889': 'v',
#  '2891': 'items',
#  '2898': 'ndarray',
#  '2900': 'generic',
#  '2908': 'item',
#  '2918': 'send_as_json',
#  '2922': 'post',
#  '2925': 'root',
#  '2927': 'path',
#  '2932': 'headers',
#  '2936': 'post',
#  '2939': 'root',
#  '2941': 'path',
#  '2944': 'field',
#  '2947': 'dumps',
#  '2951': 'headers',
#  '2954': 'RequestException',
#  '2955': 'exceptions',
#  '2959': 'warn',
#  '2965': 'root',
#  '2973': 'self',
#  '2974': 'schedule',
#  '2975': 'verbose',
#  '2979': '__init__',
#  '2985': 'schedule',
#  '2989': 'verbose',
#  '2994': 'self',
#  '2995': 'epoch',
#  '2996': 'logs',
#  '3002': 'optimizer',
#  '3003': 'model',
#  '3011': 'lr',
#  '3015': 'get_value',
#  '3017': 'lr',
#  '3018': 'optimizer',
#  '3019': 'model',
#  '3023': 'lr',
#  '3025': 'schedule',
#  '3032': 'lr',
#  '3034': 'schedule',
#  '3044': 'float32',
#  '3046': 'float64',
#  '3054': 'set_value',
#  '3056': 'lr',
#  '3057': 'optimizer',
#  '3058': 'model',
#  '3063': 'verbose',
#  '3078': 'self',
#  '3079': 'epoch',
#  '3080': 'logs',
#  '3083': 'logs',
#  '3093': 'get_value',
#  '3095': 'lr',
#  '3096': 'optimizer',
#  '3097': 'model',
#  '3105': 'self',
#  '3106': 'log_dir',
#  '3107': 'histogram_freq',
#  '3108': 'batch_size',
#  '3109': 'write_graph',
#  '3110': 'write_grads',
#  '3111': 'write_images',
#  '3112': 'embeddings_freq',
#  '3113': 'embeddings_layer_names',
#  '3114': 'embeddings_metadata',
#  '3115': 'embeddings_data',
#  '3116': 'update_freq',
#  '3130': '__init__',
#  '3150': 'backend',
#  '3160': 'warn',
#  '3164': 'histogram_freq',
#  '3170': 'warn',
#  '3174': 'write_graph',
#  '3180': 'warn',
#  '3184': 'write_images',
#  '3192': 'warn',
#  '3196': 'embeddings_freq',
#  '3199': 'log_dir',
#  '3203': 'histogram_freq',
#  '3207': 'merged',
#  '3211': 'write_graph',
#  '3215': 'write_grads',
#  '3219': 'write_images',
#  '3223': 'embeddings_freq',
#  '3227': 'embeddings_layer_names',
#  '3231': 'embeddings_metadata',
#  '3237': 'batch_size',
#  '3241': 'embeddings_data',
#  '3249': 'update_freq',
#  '3253': 'update_freq',
#  '3257': 'samples_seen',
#  '3261': 'samples_seen_at_last_write',
#  '3266': 'self',
#  '3267': 'model',
#  '3269': 'model',
#  '3275': 'backend',
#  '3279': 'sess',
#  '3282': 'get_session',
#  '3286': 'histogram_freq',
#  '3289': 'merged',
#  '3293': 'layer',
#  '3294': 'layers',
#  '3295': 'model',
#  '3298': 'weight',
#  '3299': 'weights',
#  '3302': 'mapped_weight_name',
#  '3304': 'replace',
#  '3305': 'name',
#  '3311': 'histogram',
#  '3312': 'summary',
#  '3317': 'write_grads',
#  '3320': 'grads',
#  '3322': 'get_gradients',
#  '3323': 'optimizer',
#  '3325': 'total_loss',
#  '3330': 'grad',
#  '3333': '__name__',
#  '3339': 'grads',
#  '3345': 'values',
#  '3349': 'grad',
#  '3353': 'histogram',
#  '3354': 'summary',
#  '3357': 'format',
#  '3362': 'write_images',
#  '3365': 'w_img',
#  '3367': 'squeeze',
#  '3371': 'shape',
#  '3373': 'int_shape',
#  '3393': 'w_img',
#  '3395': 'transpose',
#  '3399': 'shape',
#  '3401': 'int_shape',
#  '3405': 'w_img',
#  '3407': 'reshape',
#  '3430': 'image_data_format',
#  '3434': 'w_img',
#  '3436': 'transpose',
#  '3445': 'shape',
#  '3447': 'int_shape',
#  '3451': 'w_img',
#  '3453': 'reshape',
#  '3477': 'w_img',
#  '3479': 'reshape',
#  '3492': 'shape',
#  '3494': 'int_shape',
#  '3516': 'image',
#  '3517': 'summary',
#  '3529': 'output',
#  '3534': 'i',
#  '3535': 'output',
#  '3538': 'output',
#  '3542': 'histogram',
#  '3543': 'summary',
#  '3546': 'format',
#  '3548': 'name',
#  '3554': 'histogram',
#  '3555': 'summary',
#  '3558': 'format',
#  '3560': 'name',
#  '3562': 'output',
#  '3565': 'merged',
#  '3568': 'merge_all',
#  '3569': 'summary',
#  '3572': 'write_graph',
#  '3575': 'writer',
#  '3578': 'FileWriter',
#  '3579': 'summary',
#  '3581': 'log_dir',
#  '3583': 'graph',
#  '3584': 'sess',
#  '3587': 'writer',
#  '3590': 'FileWriter',
#  '3591': 'summary',
#  '3593': 'log_dir',
#  '3597': 'embeddings_freq',
#  '3600': 'embeddings_data',
#  '3604': 'embeddings_data',
#  '3608': 'embeddings_data',
#  '3610': 'input_names',
#  '3613': 'embeddings_layer_names',
#  '3614': 'embeddings_layer_names',
#  '3620': 'embeddings_layer_names',
#  '3622': 'name',
#  '3625': 'layer',
#  '3626': 'layers',
#  '3627': 'model',
#  '3630': '__name__',
#  '3636': 'assign_embeddings',
#  '3640': 'embeddings_vars',
#  '3643': 'batch_id',
#  '3645': 'batch_id',
#  '3647': 'placeholder',
#  '3649': 'int32',
#  '3652': 'step',
#  '3654': 'step',
#  '3656': 'placeholder',
#  '3658': 'int32',
#  '3661': 'layer',
#  '3662': 'layers',
#  '3663': 'model',
#  '3667': 'name',
#  '3671': 'embedding_input',
#  '3672': 'output',
#  '3674': 'get_layer',
#  '3675': 'model',
#  '3677': 'name',
#  '3680': 'embedding_size',
#  '3682': 'prod',
#  '3685': 'shape',
#  '3690': 'embedding_input',
#  '3692': 'reshape',
#  '3701': 'shape',
#  '3704': 'shape',
#  '3706': 'embeddings_data',
#  '3716': 'embedding',
#  '3718': 'Variable',
#  '3721': 'zeros',
#  '3726': 'name',
#  '3733': 'name',
#  '3737': 'batch',
#  '3739': 'assign',
#  '3751': 'append',
#  '3752': 'assign_embeddings',
#  '3756': 'saver',
#  '3759': 'Saver',
#  '3760': 'train',
#  '3765': 'values',
#  '3768': 'embeddings_metadata',
#  '3774': 'embeddings_metadata',
#  '3778': 'embeddings_metadata',
#  '3779': 'embeddings_metadata',
#  '3782': 'embeddings_metadata',
#  '3785': 'embeddings_metadata',
#  '3788': 'layer_name',
#  '3790': 'keys',
#  '3793': 'config',
#  '3795': 'ProjectorConfig',
#  '3799': 'layer_name',
#  '3800': 'tensor',
#  '3802': 'items',
#  '3805': 'embedding',
#  '3807': 'add',
#  '3808': 'embeddings',
#  '3811': 'tensor_name',
#  '3813': 'name',
#  '3820': 'metadata_path',
#  '3828': 'visualize_embeddings',
#  '3830': 'writer',
#  '3835': 'self',
#  '3836': 'epoch',
#  '3837': 'logs',
#  '3840': 'logs',
#  '3847': 'validation_data',
#  '3849': 'histogram_freq',
#  '3858': 'embeddings_data',
#  '3861': 'embeddings_freq',
#  '3869': 'validation_data',
#  '3871': 'histogram_freq',
#  '3877': 'histogram_freq',
#  '3881': 'val_data',
#  '3882': 'validation_data',
#  '3885': 'tensors',
#  '3888': 'inputs',
#  '3889': 'model',
#  '3891': 'targets',
#  '3892': 'model',
#  '3894': 'sample_weights',
#  '3895': 'model',
#  '3898': 'uses_learning_phase',
#  '3899': 'model',
#  '3902': 'tensors',
#  '3905': 'learning_phase',
#  '3916': 'val_size',
#  '3918': 'shape',
#  '3926': 'i',
#  '3933': 'step',
#  '3936': 'batch_size',
#  '3942': 'uses_learning_phase',
#  '3943': 'model',
#  '3946': 'batch_val',
#  '3956': 'x',
#  '3964': 'append',
#  '3972': 'batch_val',
#  '3982': 'x',
#  '3993': 'feed_dict',
#  '4001': 'result',
#  '4003': 'run',
#  '4004': 'sess',
#  '4007': 'merged',
#  '4012': 'summary_str',
#  '4019': 'add_summary',
#  '4020': 'writer',
#  '4025': 'i',
#  '4026': 'batch_size',
#  '4030': 'embeddings_freq',
#  '4033': 'embeddings_data',
#  '4040': 'embeddings_freq',
#  '4044': 'embeddings_data',
#  '4045': 'embeddings_data',
#  '4048': 'n_samples',
#  '4050': 'shape',
#  '4058': 'i',
#  '4065': 'step',
#  '4068': 'batch_size',
#  '4074': 'batch',
#  '4085': 'input',
#  '4086': 'model',
#  '4090': 'feed_dict',
#  '4102': 'idx',
#  '4103': '_input',
#  '4106': 'input',
#  '4107': 'model',
#  '4110': 'feed_dict',
#  '4112': 'input',
#  '4113': 'model',
#  '4124': 'update',
#  '4127': 'batch_id',
#  '4129': 'step',
#  '4134': 'uses_learning_phase',
#  '4135': 'model',
#  '4142': 'learning_phase',
#  '4147': 'run',
#  '4148': 'sess',
#  '4150': 'assign_embeddings',
#  '4156': 'save',
#  '4157': 'saver',
#  '4159': 'sess',
#  '4162': 'join',
#  '4163': 'path',
#  '4165': 'log_dir',
#  '4170': 'i',
#  '4171': 'batch_size',
#  '4175': 'update_freq',
#  '4179': 'index',
#  '4182': 'index',
#  '4183': 'samples_seen',
#  '4187': '_write_logs',
#  '4193': 'self',
#  '4194': 'logs',
#  '4195': 'index',
#  '4198': 'name',
#  '4199': 'value',
#  '4201': 'items',
#  '4211': 'summary',
#  '4213': 'Summary',
#  '4216': 'summary_value',
#  '4218': 'add',
#  '4219': 'value',
#  '4225': 'ndarray',
#  '4228': 'simple_value',
#  '4231': 'item',
#  '4234': 'simple_value',
#  '4238': 'tag',
#  '4243': 'add_summary',
#  '4244': 'writer',
#  '4250': 'flush',
#  '4251': 'writer',
#  '4255': 'self',
#  '4256': '_',
#  '4259': 'close',
#  '4260': 'writer',
#  '4264': 'self',
#  '4265': 'batch',
#  ...}

# %%
flatten = lambda l: [y for x in l for y in x]

# %%
import csv

# %%
with open('token_names.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
        token_names = row

# %%
import re

# %%
def camel_case_split(identifier):
    matches = re.finditer('.+?(?:(?<=[a-z])(?=[A-Z])|(?<=[A-Z])(?=[A-Z][a-z])|$)', identifier)
    return [m.group(0) for m in matches]

# %%
vocab = list(set(var_map.values()))

# %%
split_vocab = [v.split('_') for v in vocab]
split_vocab
# Out:
# [['', 'recurrent', 'dropout', 'mask'],
#  ['output', 'mask'],
#  ['recurrent', 'constraint'],
#  ['string', ''],
#  ['rmtree'],
#  ['', 'SEQUENCE', 'COUNTER'],
#  ['moving', 'mean'],
#  ['numdigits'],
#  ['cpu', 'merge'],
#  ['module', 'objects'],
#  ['first', 'layer'],
#  ['node'],
#  ['element', 'select'],
#  ['avg'],
#  ['yt'],
#  ['metrics'],
#  ['total', 'size'],
#  ['batch', 'array'],
#  ['directory'],
#  ['n'],
#  ['original', 'node', 'index'],
#  ['rnn'],
#  ['param', 'values'],
#  ['stride', 'd'],
#  ['hsplit'],
#  ['cell', 'contents'],
#  ['input', 'h'],
#  ['separable', 'conv2d'],
#  ['cols'],
#  ['tensor', 'shape'],
#  ['tensor', 'connection'],
#  ['cuda'],
#  ['model', 'weights', 'group'],
#  ['state', 'updates'],
#  ['seen'],
#  ['legacy', 'zeropadding2d', 'support'],
#  ['x', 'aggregate'],
#  ['u'],
#  ['block', 'size'],
#  ['shared'],
#  ['cache', 'dir'],
#  ['TimeseriesGenerator'],
#  ['download'],
#  ['b', 'carry'],
#  ['inbound', 'names'],
#  ['slice', 'row'],
#  ['sparse', 'tensor', 'to', 'dense'],
#  ['subset'],
#  ['open'],
#  ['max', 'pool3d'],
#  ['sha256'],
#  ['transpose'],
#  ['session', 'kwargs'],
#  ['on', 'train', 'begin'],
#  ['inner', 'input', 'shape'],
#  ['successive', 'outputs'],
#  ['W', 'constraint'],
#  ['not', 'full'],
#  ['where'],
#  ['depthwise', 'conv2d'],
#  ['input'],
#  ['Variable'],
#  ['mask', 'shape'],
#  ['Pool'],
#  ['std'],
#  ['csv', 'file'],
#  ['assign', 'sub'],
#  ['t'],
#  ['second', 'log'],
#  ['depthwise', 'initializer'],
#  ['output', 'generator'],
#  ['gpu', 'id'],
#  ['AVG', 'POOLING'],
#  ['h', 'f'],
#  ['labels', 'train'],
#  ['set'],
#  ['recurrent', 'r'],
#  ['root', 'gradients'],
#  ['tmp', 'target', 'tensors'],
#  ['legacy', 'conv3d', 'support'],
#  ['concatenate'],
#  ['dense', 'mask'],
#  ['stateful', 'metric', 'functions'],
#  ['closure'],
#  ['d', 'decoded'],
#  ['repeat'],
#  ['GlobalAvgPool2D'],
#  ['batch', 'set', 'value'],
#  ['norms'],
#  ['split', 'at'],
#  ['z0'],
#  ['sharedvar'],
#  ['height', 'factor'],
#  ['active'],
#  ['opt'],
#  ['bias', 'i', 'i'],
#  ['get', 'default', 'graph'],
#  ['output', 'size'],
#  ['explicitly', 'on', 'cpu'],
#  ['read'],
#  ['value', 'conversions'],
#  ['predict', 'on', 'batch'],
#  ['', 'input'],
#  ['alpha'],
#  ['arrays'],
#  ['tf', 'dtype'],
#  ['', 'add', 'inbound', 'node'],
#  ['datadir', 'base'],
#  ['y', 'pred'],
#  ['verbose'],
#  ['common', 'factor'],
#  ['left', 'pad'],
#  ['slice', 'length'],
#  ['', 'output', 'layers'],
#  ['mask'],
#  ['batch', 'count'],
#  ['ones'],
#  ['normalize', 'batch', 'in', 'training'],
#  ['layer', 'weights'],
#  ['alpha', 'initializer'],
#  ['gamma', 'constraint'],
#  ['dim2', 'cropping'],
#  ['build'],
#  ['Xception'],
#  ['depthwise', 'constraint'],
#  ['cond', 'shape'],
#  ['assign', 'embeddings'],
#  ['broadcast', 'moving', 'mean'],
#  ['set', 'global', 'option'],
#  ['h', 'tm1', 'h'],
#  ['W'],
#  ['svd'],
#  ['rescale'],
#  ['full', 'input', 'spec'],
#  ['weights'],
#  ['broadcast', 'as'],
#  ['full', 'input'],
#  ['num', 'words'],
#  ['rnn', 'layer'],
#  ['batch', 'axis'],
#  ['sublayer'],
#  ['input', 'layer'],
#  ['when'],
#  ['layers', 'with', 'complete', 'input'],
#  ['uses', 'learning', 'phase'],
#  ['queue'],
#  ['exceptions'],
#  ['fn'],
#  ['batch', 'normalization', 'test'],
#  ['arg', 'dict'],
#  ['is', 'placeholder'],
#  ['new', 'dim'],
#  ['layer', 'group'],
#  ['InferredDimension'],
#  ['loss', 'weight'],
#  ['args'],
#  ['', '', 'version', '', ''],
#  ['th', 'padding'],
#  ['mode'],
#  ['legacy', 'spatialdropoutNd', 'support'],
#  ['convert', 'to', 'tensor'],
#  ['x', 'f'],
#  ['hexdigest'],
#  ['recurrent', 'activation'],
#  ['nodes', 'depths'],
#  ['state', 'size'],
#  ['stateful', 'metrics'],
#  ['greater'],
#  ['CudnnLSTM'],
#  ['get', 'uid'],
#  ['kernel', 'initializer'],
#  ['grads'],
#  ['simple', 'value'],
#  ['new', 'd', 'a'],
#  ['slice', 'i'],
#  ['default', 'options'],
#  ['call'],
#  ['kernel', 'i'],
#  ['target', 'dim'],
#  ['less'],
#  ['', ''],
#  ['state', 'spec'],
#  ['mask', 'slice'],
#  ['pointwise', 'initializer'],
#  ['hh'],
#  ['embedding', 'input'],
#  ['cntk', 'shape'],
#  ['zero'],
#  ['m', 'schedule', 'next'],
#  ['weight', 'type'],
#  ['pool', '3d'],
#  ['line', 'length'],
#  ['recurrent', 'bias', 'z'],
#  ['save', 'weights', 'only'],
#  ['tile', 'shape'],
#  ['version'],
#  ['xm'],
#  ['phase'],
#  ['compute', 'mask'],
#  ['f', 'stats'],
#  ['one'],
#  ['write', 'grads'],
#  ['output', 'dim'],
#  ['', 'non', 'trainable', 'weights'],
#  ['test', 'function'],
#  ['Summary'],
#  ['integer'],
#  ['embeddings'],
#  ['preprocessing', 'function'],
#  ['cval'],
#  ['save', 'img'],
#  ['skip', 'idxs'],
#  ['softmax'],
#  ['output', 'dimensions'],
#  ['postfix', 'shape'],
#  ['vertical', 'flip'],
#  ['', 'states'],
#  ['', 'delta', 't', 'batch'],
#  ['mask', 't'],
#  ['batch', 'input', 'shape'],
#  ['batch', 'size'],
#  ['s'],
#  ['predict'],
#  ['rnn', 'inputs'],
#  ['pointwise', 'constraint'],
#  ['val', 'x'],
#  ['restore', 'best', 'weights'],
#  ['beta', 'constraint'],
#  ['generator'],
#  ['', 'output'],
#  ['image', 'data', 'format'],
#  ['val', 'sample', 'weight'],
#  ['metadata', 'path'],
#  ['replace', 'placeholders'],
#  ['cropping', 'all', 'dims'],
#  ['', 'GLOBAL', 'CUSTOM', 'OBJECTS'],
#  ['axis', 'without', 'batch'],
#  ['batch', 'logs'],
#  ['fit'],
#  ['width', 'padding'],
#  ['batch', 'start'],
#  ['deconv', 'length'],
#  ['shape1'],
#  ['list', 'devices'],
#  ['channel', 'shift', 'range'],
#  ['', 'make', 'callable', 'from', 'options'],
#  ['elems'],
#  ['allowed', 'positional', 'args'],
#  ['fields'],
#  ['placeholder', 'with', 'default'],
#  ['smoothed', 'predict'],
#  ['tanh'],
#  ['count', 'mode'],
#  ['filename'],
#  ['trainer', 'output'],
#  ['max', 'num', 'labels', 'tns'],
#  ['totals'],
#  ['spatial', '2d', 'padding'],
#  ['batch', 'get', 'value'],
#  ['min', 'delta'],
#  ['POSITIONAL', 'OR', 'KEYWORD'],
#  ['cpu', 'relocation'],
#  ['varkw'],
#  ['ctc', 'loss'],
#  ['Deconvolution3D'],
#  ['kernel', 'size'],
#  ['adj', 'x'],
#  ['const', 'a'],
#  ['unroll'],
#  ['swapaxes'],
#  ['dilation'],
#  ['featurewise', 'center'],
#  ['original', 'input', 'spec'],
#  ['initial', 'states'],
#  ['gradients'],
#  ['normalize'],
#  ['stateful', 'metric', 'names'],
#  ['', '', 'name', '', ''],
#  ['default'],
#  ['', 'SHARED', 'SEQUENCES'],
#  ['ndim', 'cond'],
#  ['', 'TensorLike'],
#  ['sleep'],
#  ['zca', 'whitening'],
#  ['requests'],
#  ['mask', 'i'],
#  ['legacy', 'lambda', 'support'],
#  ['regularization'],
#  ['hash', 'algorithm'],
#  ['current'],
#  ['wait', 'time'],
#  ['access'],
#  ['', 'EPSILON'],
#  ['allowed', 'kwargs'],
#  ['structured', 'dot'],
#  ['Optimizer'],
#  ['noise', 'shape'],
#  ['legacy', 'pooling2d', 'support'],
#  ['candidate', 'vars'],
#  ['axis'],
#  ['max', 'queue', 'size'],
#  ['predict', 'function'],
#  ['legal', 'params', 'fns'],
#  ['pad'],
#  ['input', 'ndims'],
#  ['input', 'shape'],
#  ['inputs', 'r'],
#  ['kept', 'idx'],
#  ['', 'init', 'graph', 'network'],
#  ['skip', 'mismatch'],
#  ['save'],
#  ['averages'],
#  ['learning', 'phase'],
#  ['tolist'],
#  ['d'],
#  ['beta', '1'],
#  ['unpickle', 'model'],
#  ['ctc', 'beam', 'search', 'decoder'],
#  ['condition'],
#  ['set', 'value'],
#  ['y', 'test'],
#  ['feed'],
#  ['loss'],
#  ['resize', 'nearest', 'neighbor'],
#  ['go', 'backwards'],
#  ['uses', 'lp'],
#  ['start', 'char'],
#  ['constants'],
#  ['train', 'on', 'batch'],
#  ['spatial', 'axes'],
#  ['clipvalue'],
#  ['skip', 'target', 'indices'],
#  ['layer', 'output', 'tensors'],
#  ['inc', 'subtensor'],
#  ['logits'],
#  ['dense'],
#  ['expand', 'dims'],
#  ['Edge'],
#  ['delta', 't', 'median'],
#  ['', 'initial', 'weights'],
#  ['var'],
#  ['gens'],
#  ['', 'SESSION'],
#  ['else', 'expression', 'fn'],
#  ['zeros'],
#  ['unit', 'forget', 'bias'],
#  ['converted'],
#  ['get'],
#  ['output', 'metrics'],
#  ['batch', 'shape'],
#  ['h', 'o'],
#  ['function', 'type'],
#  ['mutex'],
#  ['', 'axes'],
#  ['input', 'length', 'step'],
#  ['', 'u'],
#  ['computed', 'masks'],
#  ['xt'],
#  ['history'],
#  ['array', 'to', 'img'],
#  ['uint8'],
#  ['cond', 'ndim'],
#  ['log', 'b', 'probs'],
#  ['forward'],
#  ['samples'],
#  ['z1'],
#  ['GlobalMaxPool3D'],
#  ['sparse', 'categorical', 'crossentropy'],
#  ['get', 'value'],
#  ['', 'feed', 'output', 'names'],
#  ['binomial'],
#  ['tensor', 'index'],
#  ['normalize', 'data', 'format'],
#  ['create', 'dataset'],
#  ['w', 'pad'],
#  ['', 'legacy', 'call'],
#  ['load', 'weights', 'from', 'hdf5', 'group'],
#  ['loss', 'name'],
#  ['adamax'],
#  ['unpack'],
#  ['layer', 'data'],
#  ['inputs', 'z'],
#  ['dim', 'ordering'],
#  ['moments'],
#  ['vhat', 't'],
#  ['image', 'data', 'generator'],
#  ['kernel', 'w'],
#  ['h5py'],
#  ['visualize', 'embeddings'],
#  ['inbound', 'tensor', 'index'],
#  ['val', 'enqueuer'],
#  ['file'],
#  ['kwd'],
#  ['floatx'],
#  ['median'],
#  ['forward', 'losses'],
#  ['new', 'layer'],
#  ['col'],
#  ['output', 'values'],
#  ['parts'],
#  ['vhat'],
#  ['file', 'path'],
#  ['layer', 'weights', 'shape'],
#  ['prod'],
#  ['tensor', 'indices'],
#  ['y', 'true'],
#  ['get', 'session'],
#  ['cond'],
#  ['py', 'any'],
#  ['progbar'],
#  ['Inf'],
#  ['backward', 'state'],
#  ['regularizer'],
#  ['num', 'test'],
#  ['n', 'classes', ''],
#  ['device', 'type'],
#  ['concat'],
#  ['temporal', 'padding'],
#  ['csr', 'matrix'],
#  ['tuples'],
#  ['callback'],
#  ['ProgbarLogger'],
#  ['bad', 'attributes'],
#  ['instance'],
#  ['TensorVariable'],
#  ['Constant'],
#  ['co', 'name'],
#  ['use', 'multiprocessing'],
#  ['reset', 'after'],
#  ['get', 'layer'],
#  ['gather', 'nd'],
#  ['input', 'dtype'],
#  ['barstr'],
#  ['add', 'loss'],
#  ['max', 'norm'],
#  ['output', 'keras', 'shape'],
#  ['filters'],
#  ['reverse', 'state', 'order'],
#  ['', 'feed', 'loss', 'fns'],
#  ['unconcatenated', 'outs'],
#  ['out', 'filters'],
#  ['right', 'pad'],
#  ['assign', 'add'],
#  ['old', 'name'],
#  ['normalized', 'axis'],
#  ['on', 'epoch', 'begin'],
#  ['previous', 'feature', 'map', 'shape'],
#  ['DenseNet201'],
#  ['oh'],
#  ['avg', 'pool'],
#  ['generator', 'output'],
#  ['predict', 'loop'],
#  ['TensorSharedVariable'],
#  ['depth', 'multiplier'],
#  ['recurrent', 'h'],
#  ['end', 'index'],
#  ['recurrent', 'kernel', 'h'],
#  ['targets', 'values'],
#  ['actual', 'dim'],
#  ['initializer'],
#  ['all', 'classes'],
#  ['weighted', 'losses'],
#  ['height', 'cropping'],
#  ['h', 'tm1', 'r'],
#  ['sum'],
#  ['isinf'],
#  ['negative', 'slope'],
#  ['bias', 'c'],
#  ['num', 'old', 'batch'],
#  ['output', 'shape'],
#  ['finished', 'nodes'],
#  ['newly', 'created', 'input', 'layer'],
#  ['identity'],
#  ['num', 'dynamic'],
#  ['states', 'at', 'step'],
#  ['predict', 'classes'],
#  ['dynamic', 'axis', 'index'],
#  ['bilinear', 'upsampling'],
#  ['imgpath'],
#  ['allow', 'tuple'],
#  ['momentum', 'cache', 't'],
#  ['', 'keras', 'shape'],
#  ['', 'epsilon'],
#  ['set', 'subtensor'],
#  ['find', 'all', 'with', 'name'],
#  ['cell', 'config'],
#  ['metric', 'name'],
#  ['keras', 'shape'],
#  ['non', 'trainable', 'weights'],
#  ['GlobalAvgPool3D'],
#  ['inner', 'inputs'],
#  ['maxlen'],
#  ['hard', 'sigmoid'],
#  ['num', 'states'],
#  ['first', 'connection'],
#  ['constraints'],
#  ['legacy', 'separable', 'conv2d', 'support'],
#  ['chunk'],
#  ['bn'],
#  ['W', 'OK'],
#  ['out', 'labels'],
#  ['g'],
#  ['GlobalAvgPool1D'],
#  ['h'],
#  ['output', 'ta', 't'],
#  ['orthogonal'],
#  ['Node'],
#  ['batch', 'normalization'],
#  ['element', 'min'],
#  ['', 't', 'enter', 'batch'],
#  ['line'],
#  ['min', 'lr'],
#  ['matmul'],
#  ['slice'],
#  ['kwargs'],
#  ['network', 'nodes'],
#  ['log', 'dir'],
#  ['original', 'fm', 'shape'],
#  ['bias', 'o', 'i'],
#  ['connections'],
#  ['tocoo'],
#  ['legacy', 'dense', 'support'],
#  ['DenseNet121'],
#  ['samples', 'seen', 'at', 'last', 'write'],
#  ['get', 'monitor', 'value'],
#  ['weighted', 'loss'],
#  ['resize', 'bilinear'],
#  ['feed', 'output', 'names'],
#  ['extract'],
#  ['deserialized'],
#  ['backward', 'weights'],
#  ['inbound', 'layer', 'id'],
#  ['legacy', 'convlstm2d', 'support'],
#  ['', 'open', 'args'],
#  ['reshape'],
#  ['rho'],
#  ['fit', 'args'],
#  ['', 'assign', 'op'],
#  ['num', 'chunks'],
#  ['', 'delta', 'ts', 'batch', 'end'],
#  ['endswith'],
#  ['output', 'tensors'],
#  ['extractall'],
#  ['vstack'],
#  ['v', 't', 'prime'],
#  ['use', 'bias'],
#  ['FreeDimension'],
#  ['random', 'seed'],
#  ['batch'],
#  ['DirectoryIterator'],
#  ['input', 'length'],
#  ['stateful', 'metric', 'indices'],
#  ['layer', 'id'],
#  ['loss', 'function'],
#  ['new', 'keywords'],
#  ['min', 'ndim'],
#  ['format'],
#  ['new', 'values'],
#  ['preprocessor'],
#  ['opt', 'update'],
#  ['fpath', 'file'],
#  ['fetches'],
#  ['dim1', 'cropping'],
#  ['recurrent', 'dropout'],
#  ['py', 'all'],
#  ['inp'],
#  ['out', 'pad'],
#  ['nodes', 'by', 'depth'],
#  ['unique', 'tensors'],
#  ['legacy', 'embedding', 'support'],
#  ['callbacks'],
#  ['inputs', 'f'],
#  ['square', 'sum'],
#  ['', 'is', 'graph', 'network'],
#  ['clip'],
#  ['param', 'dset'],
#  ['data', 'npy'],
#  ['steps', 'done'],
#  ['unique', 'name'],
#  ['num', 'element'],
#  ['logs'],
#  ['broadcast', 'moving', 'variance'],
#  ['time'],
#  ['workers'],
#  ['trainable'],
#  ['proba'],
#  ['separable', 'conv1d'],
#  ['idxs'],
#  ['qsize'],
#  ['compute', 'output', 'shape'],
#  ['L1L2'],
#  ['out', 'dim'],
#  ['space'],
#  ['Event'],
#  ['order'],
#  ['feed', 'symbols'],
#  ['MethodType'],
#  ['pointwise', 'kernel', 'shape'],
#  ['text', 'to', 'word', 'sequence'],
#  ['loads'],
#  ['n', 's'],
#  ['hasher'],
#  ['random', 'normal', 'initializer'],
#  ['input', 'uid'],
#  ['reference', 'input', 'tensors'],
#  ['lower'],
#  ['', 'updates'],
#  ['post'],
#  ['', 'wait', 'queue'],
#  ['foldr'],
#  ['optimizer', 'config'],
#  ['', 'dynamic', 'display'],
#  ['inputs', 'i'],
#  ['step', 'index'],
#  ['xs'],
#  ['', 'standardize', 'args'],
#  ['expr', 'ndim'],
#  ['training', 'updates'],
#  ['to', 'sequence'],
#  ['square'],
#  ['mapped', 'weight', 'name'],
#  ['new', 'output'],
#  ['all', 'outs'],
#  ['inf'],
#  ['kernels'],
#  ['SparseType'],
#  ['i', 's'],
#  ['searchsorted'],
#  ['label'],
#  ['archive', 'format'],
#  ['symbolic', 'shape'],
#  ['targets'],
#  ['legacy', 'model', 'constructor', 'support'],
#  ['out', 'pad', 'h'],
#  ['MAE'],
#  ['File'],
#  ['outputs'],
#  ['py', 'slice'],
#  ['ndim', 'diff'],
#  ['original', 'input', 'layer'],
#  ['NASNetMobile'],
#  ['normalizer'],
#  ['stddev'],
#  ['MAPE'],
#  ['NAME', 'SCOPE', 'STACK'],
#  ['mape'],
#  ['act'],
#  ['dnn', 'batch', 'normalization', 'train'],
#  ['slices', 'dims'],
#  ['get', 'updates'],
#  ['schedule', 'decay'],
#  ['legacy', 'conv2d', 'support'],
#  ['new', 'a'],
#  ['url'],
#  ['c', 'tm1'],
#  ['mean'],
#  ['eye'],
#  ['ge'],
#  ['Deconv2D'],
#  ['gamma'],
#  ['nv'],
#  ['prog', 'width'],
#  ['preds'],
#  ['array'],
#  ['legacy', 'upsampling1d', 'support'],
#  ['time', 'per', 'unit'],
#  ['s1'],
#  ['recurrent', 'bias', 'h'],
#  ['u', 't'],
#  ['add', 'weight'],
#  ['reference', 'output', 'tensors'],
#  ['computed', 'mask'],
#  ['param'],
#  ['skip', 'top'],
#  ['label', 'shape'],
#  ['val', 'gen'],
#  ['batch', 'end'],
#  ['no', 'flip'],
#  ['errno'],
#  ['', 'feed', 'input', 'names'],
#  ['d', 'pad'],
#  ['categorical'],
#  ['inbound', 'node', 'index'],
#  ['stride', 'row'],
#  ['validation', 'data'],
#  ['alias'],
#  ['HDF5', 'OBJECT', 'HEADER', 'LIMIT'],
#  ['in', 'lens'],
#  ['pointwise', 'kernel'],
#  ['prefix', 'shape'],
#  ['input', 'data', 'shape'],
#  ['to', 'int32'],
#  ['inputs', 'h'],
#  ['inbound', 'layer', 'name'],
#  ['name'],
#  ['clipnorm'],
#  ['supports', 'masking'],
#  ['input', 'row'],
#  ['x', 'h'],
#  ['random', 'channel', 'shift'],
#  ['generate', 'legacy', 'method', 'interface'],
#  ['shuffle'],
#  ['get', 'lock'],
#  ['v', 't'],
#  ['alpha', 'regularizer'],
#  ['computed', 'data'],
#  ['', 'cudnn', 'lstm'],
#  ['recurrent', 'bias', 'r'],
#  ['layer', 'indices'],
#  ['spatial', '3d', 'padding'],
#  ['archive', 'type'],
#  ['cropping'],
#  ['VGG16'],
#  ['output', 'slice'],
#  ['weight', 'value', 'tuples'],
#  ['epoch'],
#  ['batch', 'id'],
#  ['origin'],
#  ['theta'],
#  ['cross', 'entropy', 'with', 'softmax'],
#  ['array', 'vals'],
#  ['', 'input', 'layers'],
#  ['copy'],
#  ['type'],
#  ['nested', 'states'],
#  ['dtype'],
#  ['moving', 'average', 'update'],
#  ['Print'],
#  ['asarray'],
#  ['function', 'name'],
#  ['legacy', 'cropping2d', 'support'],
#  ['environ'],
#  ['epsilon'],
#  ['x', 'test'],
#  ['zca', 'epsilon'],
#  ['chunk', 'id'],
#  ['sparse', 'placeholder'],
#  ['f'],
#  ['evaluate', 'generator'],
#  ['time', 'steps'],
#  ['new', 'c'],
#  ['legacy', 'spatialdropout1d', 'support'],
#  ['op'],
#  ['local', 'conv1d'],
#  ['base', 'dtype'],
#  ['previous', 'sources'],
#  ['argmax'],
#  ['layers', 'to', 'output', 'shapes'],
#  ['y', 'loc'],
#  ['input', 'list'],
#  ['recurrent', 'conv'],
#  ['TarError'],
#  ['relu'],
#  ['moving', 'mean', 'initializer'],
#  ['uninitialized', 'vars'],
#  ['History'],
#  ['broadcast'],
#  ['', 'send', 'sequence'],
#  ['then', 'expression', 'fn'],
#  ['results'],
#  ['le'],
#  ['value', 'tuple'],
#  ['l2'],
#  ['switch'],
#  ['floatX'],
#  ['m', 'schedule', 'new'],
#  ['val', 'y'],
#  ['value'],
#  ['times'],
#  ['pool3d'],
#  ['intermediate'],
#  ['stop', 'training'],
#  ['Deconvolution2D'],
#  ['relu6'],
#  ['key'],
#  ['initial', 'state'],
#  ['squeeze'],
#  ['', 'output', 'coordinates'],
#  ['update', 'freq'],
#  ['hstack'],
#  ['', 'output', 'shape'],
#  ['', 'num', 'constants'],
#  ['stride', 'h'],
#  ['shape', 'key'],
#  ['dynamic', 'axes'],
#  ['reporthook'],
#  ['send', 'as', 'json'],
#  ['stop', 'signal'],
#  ['variables'],
#  ['high'],
#  ['int32'],
#  ['equal'],
#  ['FileWriter'],
#  ['width'],
#  ['out', 'depth'],
#  ['normal', 't'],
#  ['score', 'array'],
#  ['transform', 'weight'],
#  ['CallableOptions'],
#  ['frombuffer'],
#  ['ConfigProto'],
#  ['timesteps'],
#  ['to', 'file'],
#  ['generic'],
#  ['image'],
#  ['fname'],
#  ['embedding', 'lookup'],
#  ['categorical', 'crossentropy'],
#  ['assign', 'placeholder'],
#  ['', 'cntk', 'placeholder'],
#  ['min'],
#  ['weighted', 'metric', 'fn'],
#  ['getfullargspec'],
#  ['to', 'sequence', 'like'],
#  ['empty'],
#  ['set', 'inputs'],
#  ['bias', 'z'],
#  ['output', 'masks'],
#  ['conv1d'],
#  ['states'],
#  ['max', 'ndim'],
#  ['increment'],
#  ['start', 'idx'],
#  ['dilation', 'rate'],
#  ['weight'],
#  ['element', 'max'],
#  ['log10'],
#  ['t', 'before', 'callbacks'],
#  ['path'],
#  ['TensorArray'],
#  ['log', 'first'],
#  ['merge', 'mode'],
#  ['positions'],
#  ['rep'],
#  ['Thread'],
#  ['cls', 'name'],
#  ['types'],
#  ['node', 'data'],
#  ['labels', 'test'],
#  ['auxiliary', 'axis'],
#  ['forward', 'layer'],
#  ['rate'],
#  ['first', 'log'],
#  ['m', 't', 'bar'],
#  ['timeout'],
#  ['last', 'states'],
#  ['embedding'],
#  ['known'],
#  ['', 'GRAPH', 'UID', 'DICTS'],
#  ['input', 'index'],
#  ['embeddings', 'data'],
#  ['step', 'input', 'shape'],
#  ['argmin'],
#  ['img'],
#  ['task', 'done'],
#  ['x', 'flatten'],
#  ['target', 'size'],
#  ['', 'constraint'],
#  ['old', 'value'],
#  ['fixed', 'batch', 'size'],
#  ['decay'],
#  ['mask', 'ta'],
#  ['printable', 'module', 'name'],
#  ['base', 'shape'],
#  ['callable', 'fn'],
#  ['feed', 'input', 'shapes'],
#  ['merge', 'all'],
#  ['range'],
#  ['embedding', 'size'],
#  ['convolution', 'transpose'],
#  ['predictions'],
#  ['biases'],
#  ['save', 'weights', 'to', 'hdf5', 'group'],
#  ['broadcast', 'gamma'],
#  ['GlobalMaxPool2D'],
#  ['sigmoid'],
#  ['replace'],
#  ['p'],
#  ['', 'dropout', 'mask'],
#  ['limit'],
#  ['stateful'],
#  ['sub'],
#  ['dense', 'shape'],
#  ['learner'],
#  ['model', 'outputs'],
#  ['optimizer'],
#  ['', 'pooling', 'function'],
#  ['forward', 'updates'],
#  ['regularization', 'loss'],
#  ['AbstractConv3d', 'gradInputs'],
#  ['updates', 'ops'],
#  ['recurrent', 'kernel'],
#  ['metric', 'result'],
#  ['to', 'tensor'],
#  ['recurrent', 'regularizer'],
#  ['lt'],
#  ['f', 'active'],
#  ['n', 'samples'],
#  ['previous', 'depth'],
#  ['get', 'losses', 'for'],
#  ['shared', 'axes'],
#  ['legacy', 'zeropadding3d', 'support'],
#  ['combine'],
#  ['Y'],
#  ['keys'],
#  ['', 'build', 'input', 'shape'],
#  ['samples', 'seen', 'since'],
#  ['device'],
#  ['make', 'sampling', 'table'],
#  ['root'],
#  ['output', 'tensor'],
#  ['summary', 'value'],
#  ['OrderedDict'],
#  ['reduction', 'axes'],
#  ['filter', 'sk', 'params'],
#  ['isnan'],
#  ['file', 'flags'],
#  ['layers', 'for', 'depth'],
#  ['dim3', 'cropping'],
#  ['ident'],
#  ['model', 'layers'],
#  ['flat', 'shape'],
#  ['print', 'fn'],
#  ['val', 'data'],
#  ['variables', 'initializer'],
#  ['callback', 'metrics'],
#  ['batch', 'ind'],
#  ['by', 'name'],
#  ['delta', 'accumulators'],
#  ['isfile'],
#  ['assign'],
#  ['j'],
#  ['th', 'sparse', 'module'],
#  ['new', 'arg'],
#  ['save', 'to', 'dir'],
#  ['child', 'class', 'name'],
#  ['new', 'width'],
#  ['symbol', 'vals'],
#  ['kernel', 'c'],
#  ['successive', 'states'],
#  ['abs'],
#  ['temp'],
#  ['random', 'uniform', 'initializer'],
#  ['bias', 'f'],
#  ['nbytes'],
#  ['string', 'types'],
#  ['trainable', 'count'],
#  ['feature', 'dim'],
#  ['', 'init', 'subclassed', 'network'],
#  ['', 'values'],
#  ['moves'],
#  ['chunk', 'attr'],
#  ['ki'],
#  ['metrics', 'updates'],
#  ['', 'run'],
#  ['group'],
#  ['total', 'log', 'prob'],
#  ['in', 'cooldown'],
#  ['out'],
#  ['rmsprop'],
#  ['not', 'equal'],
#  ['', 'LEARNING', 'PHASE'],
#  ['tensor'],
#  ['init'],
#  ['x', 'o'],
#  ['NumpyArrayIterator'],
#  ['kernel', 'r'],
#  ['fit', 'loop'],
#  ['unit', 'norm'],
#  ['embeddings', 'metadata'],
#  ['x', 'z'],
#  ['cosine'],
#  ['', 'is', 'compiled'],
#  ['set', 'x'],
#  ['get', 'default', 'session'],
#  ['', 'feed', 'inputs'],
#  ['get', 'config'],
#  ['reduce', 'any'],
#  ['num', 'constants'],
#  ['non', 'trainable', 'count'],
#  ['conv2d'],
#  ['ops'],
#  ['py', 'sum'],
#  ['len', 'dim2'],
#  ['reverse'],
#  ['x', 'train'],
#  ['b', 'any'],
#  ['outs', 'per', 'batch'],
#  ['node', 'conversion', 'map'],
#  ['current', 'layout'],
#  ['m', 't', 'prime'],
#  ['output', 'ls', 'copy'],
#  ['Dataset'],
#  ['', 'process', 'batch'],
#  ['len', 'dim1'],
#  ['inbound', 'nodes', 'data'],
#  ['sparse', 'softmax', 'cross', 'entropy', 'with', 'logits'],
#  ['computable', 'tensors'],
#  ['width', 'factor'],
#  ['ctc', 'greedy', 'decoder'],
#  ...]

# %%
for t in token_names:
    split_vocab.append([t])

# %%
split_vocab[2000:]
# Out:
# [['output', 'loss'],
#  ['backend'],
#  ['non', 'tensors'],
#  ['x', 'c'],
#  ['', 'callbacks'],
#  ['AvgPool3D'],
#  ['', '', 'dict', '', ''],
#  ['untar', 'fpath'],
#  ['files'],
#  ['', 'callable', 'fn'],
#  ['uid'],
#  ['', 'make', 'train', 'function'],
#  ['ins'],
#  ['batch', 'ids'],
#  ['input', 'conv'],
#  ['updated', 'log', 'p', 'prev'],
#  ['prev', 'total', 'width'],
#  ['apply', 'channel', 'shift'],
#  ['update'],
#  ['distribution'],
#  ['skip', 'target', 'weighing', 'indices'],
#  ['extend'],
#  ['iterations'],
#  ['run', 'metadata'],
#  ['has', 'seq'],
#  ['map'],
#  ['insecure'],
#  ['permute', 'dimensions'],
#  ['MSLE'],
#  ['b', 'constraint'],
#  ['rankdir'],
#  ['embeddings', 'freq'],
#  ['deepcopy'],
#  ['', 'seen', 'so', 'far'],
#  ['non', 'repeats'],
#  ['num', 'gpus'],
#  ['num', 'static', 'element'],
#  ['int', 'shape'],
#  ['active', 'skip', 'idxs'],
#  ['bool'],
#  ['proceed'],
#  ['y', 'train'],
#  ['', 'call'],
#  ['saver'],
#  ['add', 'summary'],
#  ['new', 'shape'],
#  ['rnn', 'constants'],
#  ['', 'uses', 'learning', 'phase'],
#  ['top', 'paths'],
#  ['weighted', 'metrics'],
#  ['kept', 'nodes'],
#  ['out', 'pad', 'd'],
#  ['dynamic', 'dimension'],
#  ['reduce', 'prod'],
#  ['', 'FLOATX'],
#  ['', 'node', 'key'],
#  ['kernel', 'regularizer'],
#  ['oov', 'char'],
#  ['softplus'],
#  ['truncated', 'normal'],
#  ['depth', 'keys'],
#  ['', 'make', 'callable'],
#  ['nnet'],
#  ['mask', 'list'],
#  ['sample', 'weight', 'mode'],
#  ['UserFunction'],
#  ['msg'],
#  ['slices'],
#  ['num', 'cols'],
#  ['scalar'],
#  ['unbroadcast'],
#  ['inputlabels'],
#  ['chunked', 'data'],
#  ['', 'input', 'tensors'],
#  ['legacy', 'cropping3d', 'support'],
#  ['start'],
#  ['key', 'losses'],
#  ['label', 'length'],
#  ['target', 'gpu', 'ids'],
#  ['clear'],
#  ['ZipFile'],
#  ['epochs', 'since', 'last', 'save'],
#  ['log', 'probs'],
#  ['setdefault'],
#  ['AvgPool2D'],
#  ['x', 'weight'],
#  ['last'],
#  ['normalized', 'size'],
#  ['module'],
#  ['y', 'true', 'step'],
#  ['sqrt'],
#  ['outputlabels'],
#  ['', 'standardize', 'user', 'data'],
#  ['legacy', 'batchnorm', 'support'],
#  ['tag'],
#  ['legacy', 'global', 'pooling', 'support'],
#  ['ms'],
#  ['sequential', 'like'],
#  ['bias', 'shape'],
#  ['val', 'outs'],
#  ['sgn'],
#  ['random', 'normal'],
#  ['ResNet50'],
#  ['bias', 'c', 'i'],
#  ['from', 'logits'],
#  ['', 'GRAPH', 'LEARNING', 'PHASES'],
#  ['add', 'edge'],
#  ['masks'],
#  ['md5', 'hash'],
#  ['minimum'],
#  ['input', 'bias', 'z'],
#  ['metrics', 'outputs'],
#  ['prev', 'output'],
#  ['mask', 'cache', 'key'],
#  ['as', 'default'],
#  ['current', 'process'],
#  ['first', 'val'],
#  ['readline'],
#  ['raw', 'code'],
#  ['placeholders'],
#  ['beam', 'width'],
#  ['end'],
#  ['', 'network', 'nodes'],
#  ['list', 'local', 'devices'],
#  ['write', 'images'],
#  ['num', 'rows'],
#  ['val'],
#  ['Cell'],
#  ['computed', 'tensors'],
#  ['variant'],
#  ['setter'],
#  ['legacy', 'gaussiandropout', 'support'],
#  ['variance', 'mean'],
#  ['placeholder'],
#  ['cntk', 'axes'],
#  ['initial', 'decay'],
#  ['embeddings', 'regularizer'],
#  ['is', 'zero', 'dim', 'ndarray'],
#  ['sign'],
#  ['plus'],
#  ['', 'keras', 'history'],
#  ['', 'output', 'tensor', 'cache'],
#  ['L'],
#  ['atleast', '1d'],
#  ['all', 'inputs'],
#  ['available', 'devices'],
#  ['non', 'neg'],
#  ['original', 'shape'],
#  ['label', 'mode'],
#  ['y', 'pred', 'step'],
#  ['new', 'node', 'index'],
#  ['sess'],
#  ['', 'set', 'inputs'],
#  ['spec'],
#  ['dev'],
#  ['attr'],
#  ['put'],
#  ['log'],
#  ['ProjectorConfig'],
#  ['item'],
#  ['randint'],
#  ['log', 'f', 'prev'],
#  ['NASNetLarge'],
#  ['DictWriter'],
#  ['dataset'],
#  ['samplewise', 'std', 'normalization'],
#  ['AvgPool1D'],
#  ['random', 'uniform'],
#  ['getargspec'],
#  ['created', 'layers'],
#  ['batch', 'dot'],
#  ['Group'],
#  ['init', 'tuple'],
#  ['random', 'shear'],
#  ['last', 'batch'],
#  ['executor', 'fn'],
#  ['seq'],
#  ['sep'],
#  ['depthwise', 'regularizer'],
#  ['rotation', 'range'],
#  ['as', 'list'],
#  ['AtrousConv2D'],
#  ['', 'get', 'noise', 'shape'],
#  ['kshape'],
#  ['check', 'params'],
#  ['reshaped', 'inputs'],
#  ['all', 'outputs'],
#  ['', 'layers'],
#  ['embeddings', 'initializer'],
#  ['gpus', 'available'],
#  ['feed', 'input', 'names'],
#  ['', 'output', 'shape', 'cache'],
#  ['insert'],
#  ['h5dict'],
#  ['expected', 'depth'],
#  ['count', 'params'],
#  ['schedule'],
#  ['to', 'one', 'hot'],
#  ['', 'reset'],
#  ['excel'],
#  ['new', 'name'],
#  ['parameter'],
#  ['sample', 'weight', 'modes'],
#  ['period'],
#  ['', '', 'doc', '', ''],
#  ['metrics', 'tensors'],
#  ['MobileNetV2'],
#  ['wraps'],
#  ['kernel', 'd'],
#  ['output', 'length'],
#  ['minval'],
#  ['get', 'gradients'],
#  ['z'],
#  ['variance'],
#  ['num', 'batches'],
#  ['adj', 'y'],
#  ['compute', 'gradients'],
#  ['old', 'lr'],
#  ['d', 'axis'],
#  ['pool', 'mode'],
#  ['get', 'constants'],
#  ['sparse', 'to', 'dense'],
#  ['stop', 'gradient'],
#  ['final', 'outputs'],
#  ['executor'],
#  ['', 'merge', 'function'],
#  ['num', 'time', 'step'],
#  ['output', 'shape', 'keys'],
#  ['old', 'arg'],
#  ['T'],
#  ['state', 'specs'],
#  ['deserialize'],
#  ['save', 'format'],
#  ['x', 'weights'],
#  ['recurrent', 'kernels'],
#  ['new', 'height'],
#  ['layer', 'names'],
#  ['layer', 'map'],
#  ['image', 'shape'],
#  ['kernel', 'o'],
#  ['sparse', 'categorical', 'accuracy'],
#  ['nw'],
#  ['stride', 'size'],
#  ['as', 'sparse', 'variable'],
#  ['object', 'list'],
#  ['samplewise', 'center'],
#  ['cache', 'key'],
#  ['Y', ''],
#  ['reduce', 'sum'],
#  ['delimiter'],
#  ['identifier'],
#  ['all', 'input', 'shapes'],
#  ['resize', 'volumes'],
#  ['batches'],
#  ['backward', 'updates'],
#  ['train', 'function'],
#  ['unfinished', 'tasks'],
#  ['reduce', 'min'],
#  ['', '', 'code', '', ''],
#  ['recurrent', 'kernel', 'i'],
#  ['set', 'params'],
#  ['globs'],
#  ['reduced', 'inputs', 'shapes'],
#  ['return', 'states'],
#  ['prog'],
#  ['Axis'],
#  ['fused', 'batch', 'norm'],
#  ['dnn', 'batch', 'normalization', 'test'],
#  ['less', 'equal'],
#  ['bottom', 'pad'],
#  ['b', 'skip', 'idxs'],
#  ['MobileNet'],
#  ['num', 'classes'],
#  ['seed'],
#  ['mask', 'zero'],
#  ['bias', 'regularizer'],
#  ['cw'],
#  ['bias', 'z', 'i'],
#  ['input', 'i'],
#  ['batch', 'normalization', 'train'],
#  ['reps'],
#  ['indices', 'for', 'conversion', 'to', 'dense'],
#  ['g', 'shape'],
#  ['', 'trainable'],
#  ['Convolution3D'],
#  ['trainable', 'weights'],
#  ['check', 'batch', 'axis'],
#  ['random', 'tensor'],
#  ['mask', 'value'],
#  ['CopyFrom'],
#  ['pool', '2d'],
#  ['dropout'],
#  ['output'],
#  ['class', 'mode'],
#  ['target', 'format'],
#  ['tiled', 'mask', 't'],
#  ['any'],
#  ['is', 'tarfile'],
#  ['level'],
#  ['config'],
#  ['append'],
#  ['input', 'c'],
#  ['bias', 'i'],
#  ['greedy'],
#  ['reset', 'default', 'graph'],
#  ['', '', 'module', '', ''],
#  ['num', 'batch'],
#  ['nones'],
#  ['legacy', 'deconv2d', 'support'],
#  ['SeparableConvolution2D'],
#  ['computed', 'tensor'],
#  ['extra', 'ops'],
#  ['model', 'inputs'],
#  ['multiply'],
#  ['indices'],
#  ['non', 'dyn', 'shape'],
#  ['function'],
#  ['layer', 'class', 'name'],
#  ['delete'],
#  ['forward', 'weights'],
#  ['session'],
#  ['ch', 'dim'],
#  ['', 'compute', 'elemwise', 'op', 'output', 'shape'],
#  ['log', 'b', 'next'],
#  ['kernel', 'f'],
#  ['step', 'function'],
#  ['output', 'row'],
#  ['expected', 'output', 'dtype'],
#  ['', 'IMAGE', 'DATA', 'FORMAT'],
#  ['layer', 'config'],
#  ['h', 'tm1'],
#  ['rec', 'dp', 'mask'],
#  ['inputs', 'c'],
#  ['disconnected', 'grad'],
#  ['cell', 'losses'],
#  ['to', 'display'],
#  ['weight', 'values'],
#  ['validation', 'split'],
#  ['callable', 'opts'],
#  ['is', 'chunked'],
#  ['all', 'output', 'shapes'],
#  ['softsign'],
#  ['input', 'names'],
#  ['flatten'],
#  ['neg'],
#  ['num', 'train', 'samples'],
#  ['actual', 'output', 'shape'],
#  ['sample', 'size'],
#  ['axes'],
#  ['step'],
#  ['chunk', 'size'],
#  ['default', 'batch', 'axis'],
#  ['model'],
#  ['min', 'value'],
#  ['decrement'],
#  ['min', 'max', 'norm'],
#  ['target', 'devices'],
#  ['f', 'active', 'next'],
#  ['map', 'fn'],
#  ['check', 'array', 'lengths'],
#  ['get', 'shape'],
#  ['', 'targets'],
#  ['Ones'],
#  ['VAR', 'KEYWORD'],
#  ['predict', 'proba'],
#  ['normalized'],
#  ['final', 'output'],
#  ['inner', 'mask'],
#  ['p', 'list'],
#  ['', 'collected', 'trainable', 'weights'],
#  ['splice'],
#  ['nodes', 'in', 'decreasing', 'depth'],
#  ['get', 'initial', 'state'],
#  ['legacy', 'conv1d', 'support'],
#  ['update', 'func'],
#  ['', 'dense', 'shape'],
#  ['unknown'],
#  ['object', 'name'],
#  ['', 'cudnn', 'gru'],
#  ['writeheader'],
#  ['load', 'weights', 'from', 'hdf5', 'group', 'by', 'name'],
#  ['atrous', 'conv2d', 'transpose'],
#  ['', 'get', 'executor', 'init'],
#  ['recurrent', 'kernel', 'z'],
#  ['', 'output', 'mask', 'cache'],
#  ['x', 'elem'],
#  ['bias', 'add'],
#  ['run', 'thread'],
#  ['active', 'next'],
#  ['TensorType'],
#  ['', 'expects', 'training', 'arg'],
#  ['MAX', 'POOLING'],
#  ['else', 'expression'],
#  ['new', 'p'],
#  ['prefix'],
#  ['converted', 'kernel'],
#  ['stdout'],
#  ['untar'],
#  ['Module'],
#  ['Interactive'],
#  ['Expression'],
#  ['Suite'],
#  ['FunctionDef'],
#  ['AsyncFunctionDef'],
#  ['ClassDef'],
#  ['Return'],
#  ['Delete'],
#  ['Assign'],
#  ['AugAssign'],
#  ['For'],
#  ['AsyncFor'],
#  ['While'],
#  ['If'],
#  ['With'],
#  ['AsyncWith'],
#  ['Raise'],
#  ['Try'],
#  ['Assert'],
#  ['Import'],
#  ['ImportFrom'],
#  ['Global'],
#  ['Nonlocal'],
#  ['Expr'],
#  ['Pass'],
#  ['Break'],
#  ['Continue'],
#  ['BoolOp'],
#  ['BinOp'],
#  ['UnaryOp'],
#  ['Lambda'],
#  ['IfExp'],
#  ['Dict'],
#  ['Set'],
#  ['ListComp'],
#  ['SetComp'],
#  ['DictComp'],
#  ['GeneratorExp'],
#  ['Await'],
#  ['Yield'],
#  ['YieldFrom'],
#  ['Compare'],
#  ['Call'],
#  ['Num'],
#  ['Str'],
#  ['FormattedValue'],
#  ['JoinedStr'],
#  ['Bytes'],
#  ['NameConstant'],
#  ['Ellipsis'],
#  ['Constant'],
#  ['Attribute'],
#  ['Subscript'],
#  ['Starred'],
#  ['Name'],
#  ['List'],
#  ['Tuple'],
#  ['Load'],
#  ['Store'],
#  ['Del'],
#  ['AugLoad'],
#  ['AugStore'],
#  ['Param'],
#  ['Slice'],
#  ['ExtSlice'],
#  ['Index'],
#  ['And'],
#  ['Or'],
#  ['Add'],
#  ['Sub'],
#  ['Mult'],
#  ['MatMult'],
#  ['Div'],
#  ['Mod'],
#  ['Pow'],
#  ['LShift'],
#  ['RShift'],
#  ['BitOr'],
#  ['BitXor'],
#  ['BitAnd'],
#  ['FloorDiv'],
#  ['Invert'],
#  ['Not'],
#  ['UAdd'],
#  ['USub'],
#  ['Eq'],
#  ['NotEq'],
#  ['Lt'],
#  ['LtE'],
#  ['Gt'],
#  ['GtE'],
#  ['Is'],
#  ['IsNot'],
#  ['In'],
#  ['NotIn'],
#  ['excepthandler'],
#  ['ExceptHandler'],
#  ['arguments'],
#  ['arg'],
#  ['keyword'],
#  ['alias'],
#  ['withitem'],
#  ['comprehension']]

# %%
s_vocab = []
for vs in split_vocab:
    f = []
    for v in vs:
        f.append(camel_case_split(v))
    s_vocab.append(flatten(f))

# %%
s_vocab += [['[MASK]']]

# %%
s_vocab += [['[END]']]

# %%
s_vocab += [['[UNK]']]

# %%
s_vocab[2000:]
# Out:
# [['output', 'loss'],
#  ['backend'],
#  ['non', 'tensors'],
#  ['x', 'c'],
#  ['callbacks'],
#  ['Avg', 'Pool3D'],
#  ['dict'],
#  ['untar', 'fpath'],
#  ['files'],
#  ['callable', 'fn'],
#  ['uid'],
#  ['make', 'train', 'function'],
#  ['ins'],
#  ['batch', 'ids'],
#  ['input', 'conv'],
#  ['updated', 'log', 'p', 'prev'],
#  ['prev', 'total', 'width'],
#  ['apply', 'channel', 'shift'],
#  ['update'],
#  ['distribution'],
#  ['skip', 'target', 'weighing', 'indices'],
#  ['extend'],
#  ['iterations'],
#  ['run', 'metadata'],
#  ['has', 'seq'],
#  ['map'],
#  ['insecure'],
#  ['permute', 'dimensions'],
#  ['MSLE'],
#  ['b', 'constraint'],
#  ['rankdir'],
#  ['embeddings', 'freq'],
#  ['deepcopy'],
#  ['seen', 'so', 'far'],
#  ['non', 'repeats'],
#  ['num', 'gpus'],
#  ['num', 'static', 'element'],
#  ['int', 'shape'],
#  ['active', 'skip', 'idxs'],
#  ['bool'],
#  ['proceed'],
#  ['y', 'train'],
#  ['call'],
#  ['saver'],
#  ['add', 'summary'],
#  ['new', 'shape'],
#  ['rnn', 'constants'],
#  ['uses', 'learning', 'phase'],
#  ['top', 'paths'],
#  ['weighted', 'metrics'],
#  ['kept', 'nodes'],
#  ['out', 'pad', 'd'],
#  ['dynamic', 'dimension'],
#  ['reduce', 'prod'],
#  ['FLOATX'],
#  ['node', 'key'],
#  ['kernel', 'regularizer'],
#  ['oov', 'char'],
#  ['softplus'],
#  ['truncated', 'normal'],
#  ['depth', 'keys'],
#  ['make', 'callable'],
#  ['nnet'],
#  ['mask', 'list'],
#  ['sample', 'weight', 'mode'],
#  ['User', 'Function'],
#  ['msg'],
#  ['slices'],
#  ['num', 'cols'],
#  ['scalar'],
#  ['unbroadcast'],
#  ['inputlabels'],
#  ['chunked', 'data'],
#  ['input', 'tensors'],
#  ['legacy', 'cropping3d', 'support'],
#  ['start'],
#  ['key', 'losses'],
#  ['label', 'length'],
#  ['target', 'gpu', 'ids'],
#  ['clear'],
#  ['Zip', 'File'],
#  ['epochs', 'since', 'last', 'save'],
#  ['log', 'probs'],
#  ['setdefault'],
#  ['Avg', 'Pool2D'],
#  ['x', 'weight'],
#  ['last'],
#  ['normalized', 'size'],
#  ['module'],
#  ['y', 'true', 'step'],
#  ['sqrt'],
#  ['outputlabels'],
#  ['standardize', 'user', 'data'],
#  ['legacy', 'batchnorm', 'support'],
#  ['tag'],
#  ['legacy', 'global', 'pooling', 'support'],
#  ['ms'],
#  ['sequential', 'like'],
#  ['bias', 'shape'],
#  ['val', 'outs'],
#  ['sgn'],
#  ['random', 'normal'],
#  ['Res', 'Net50'],
#  ['bias', 'c', 'i'],
#  ['from', 'logits'],
#  ['GRAPH', 'LEARNING', 'PHASES'],
#  ['add', 'edge'],
#  ['masks'],
#  ['md5', 'hash'],
#  ['minimum'],
#  ['input', 'bias', 'z'],
#  ['metrics', 'outputs'],
#  ['prev', 'output'],
#  ['mask', 'cache', 'key'],
#  ['as', 'default'],
#  ['current', 'process'],
#  ['first', 'val'],
#  ['readline'],
#  ['raw', 'code'],
#  ['placeholders'],
#  ['beam', 'width'],
#  ['end'],
#  ['network', 'nodes'],
#  ['list', 'local', 'devices'],
#  ['write', 'images'],
#  ['num', 'rows'],
#  ['val'],
#  ['Cell'],
#  ['computed', 'tensors'],
#  ['variant'],
#  ['setter'],
#  ['legacy', 'gaussiandropout', 'support'],
#  ['variance', 'mean'],
#  ['placeholder'],
#  ['cntk', 'axes'],
#  ['initial', 'decay'],
#  ['embeddings', 'regularizer'],
#  ['is', 'zero', 'dim', 'ndarray'],
#  ['sign'],
#  ['plus'],
#  ['keras', 'history'],
#  ['output', 'tensor', 'cache'],
#  ['L'],
#  ['atleast', '1d'],
#  ['all', 'inputs'],
#  ['available', 'devices'],
#  ['non', 'neg'],
#  ['original', 'shape'],
#  ['label', 'mode'],
#  ['y', 'pred', 'step'],
#  ['new', 'node', 'index'],
#  ['sess'],
#  ['set', 'inputs'],
#  ['spec'],
#  ['dev'],
#  ['attr'],
#  ['put'],
#  ['log'],
#  ['Projector', 'Config'],
#  ['item'],
#  ['randint'],
#  ['log', 'f', 'prev'],
#  ['NAS', 'Net', 'Large'],
#  ['Dict', 'Writer'],
#  ['dataset'],
#  ['samplewise', 'std', 'normalization'],
#  ['Avg', 'Pool1D'],
#  ['random', 'uniform'],
#  ['getargspec'],
#  ['created', 'layers'],
#  ['batch', 'dot'],
#  ['Group'],
#  ['init', 'tuple'],
#  ['random', 'shear'],
#  ['last', 'batch'],
#  ['executor', 'fn'],
#  ['seq'],
#  ['sep'],
#  ['depthwise', 'regularizer'],
#  ['rotation', 'range'],
#  ['as', 'list'],
#  ['Atrous', 'Conv2D'],
#  ['get', 'noise', 'shape'],
#  ['kshape'],
#  ['check', 'params'],
#  ['reshaped', 'inputs'],
#  ['all', 'outputs'],
#  ['layers'],
#  ['embeddings', 'initializer'],
#  ['gpus', 'available'],
#  ['feed', 'input', 'names'],
#  ['output', 'shape', 'cache'],
#  ['insert'],
#  ['h5dict'],
#  ['expected', 'depth'],
#  ['count', 'params'],
#  ['schedule'],
#  ['to', 'one', 'hot'],
#  ['reset'],
#  ['excel'],
#  ['new', 'name'],
#  ['parameter'],
#  ['sample', 'weight', 'modes'],
#  ['period'],
#  ['doc'],
#  ['metrics', 'tensors'],
#  ['Mobile', 'Net', 'V2'],
#  ['wraps'],
#  ['kernel', 'd'],
#  ['output', 'length'],
#  ['minval'],
#  ['get', 'gradients'],
#  ['z'],
#  ['variance'],
#  ['num', 'batches'],
#  ['adj', 'y'],
#  ['compute', 'gradients'],
#  ['old', 'lr'],
#  ['d', 'axis'],
#  ['pool', 'mode'],
#  ['get', 'constants'],
#  ['sparse', 'to', 'dense'],
#  ['stop', 'gradient'],
#  ['final', 'outputs'],
#  ['executor'],
#  ['merge', 'function'],
#  ['num', 'time', 'step'],
#  ['output', 'shape', 'keys'],
#  ['old', 'arg'],
#  ['T'],
#  ['state', 'specs'],
#  ['deserialize'],
#  ['save', 'format'],
#  ['x', 'weights'],
#  ['recurrent', 'kernels'],
#  ['new', 'height'],
#  ['layer', 'names'],
#  ['layer', 'map'],
#  ['image', 'shape'],
#  ['kernel', 'o'],
#  ['sparse', 'categorical', 'accuracy'],
#  ['nw'],
#  ['stride', 'size'],
#  ['as', 'sparse', 'variable'],
#  ['object', 'list'],
#  ['samplewise', 'center'],
#  ['cache', 'key'],
#  ['Y'],
#  ['reduce', 'sum'],
#  ['delimiter'],
#  ['identifier'],
#  ['all', 'input', 'shapes'],
#  ['resize', 'volumes'],
#  ['batches'],
#  ['backward', 'updates'],
#  ['train', 'function'],
#  ['unfinished', 'tasks'],
#  ['reduce', 'min'],
#  ['code'],
#  ['recurrent', 'kernel', 'i'],
#  ['set', 'params'],
#  ['globs'],
#  ['reduced', 'inputs', 'shapes'],
#  ['return', 'states'],
#  ['prog'],
#  ['Axis'],
#  ['fused', 'batch', 'norm'],
#  ['dnn', 'batch', 'normalization', 'test'],
#  ['less', 'equal'],
#  ['bottom', 'pad'],
#  ['b', 'skip', 'idxs'],
#  ['Mobile', 'Net'],
#  ['num', 'classes'],
#  ['seed'],
#  ['mask', 'zero'],
#  ['bias', 'regularizer'],
#  ['cw'],
#  ['bias', 'z', 'i'],
#  ['input', 'i'],
#  ['batch', 'normalization', 'train'],
#  ['reps'],
#  ['indices', 'for', 'conversion', 'to', 'dense'],
#  ['g', 'shape'],
#  ['trainable'],
#  ['Convolution3D'],
#  ['trainable', 'weights'],
#  ['check', 'batch', 'axis'],
#  ['random', 'tensor'],
#  ['mask', 'value'],
#  ['Copy', 'From'],
#  ['pool', '2d'],
#  ['dropout'],
#  ['output'],
#  ['class', 'mode'],
#  ['target', 'format'],
#  ['tiled', 'mask', 't'],
#  ['any'],
#  ['is', 'tarfile'],
#  ['level'],
#  ['config'],
#  ['append'],
#  ['input', 'c'],
#  ['bias', 'i'],
#  ['greedy'],
#  ['reset', 'default', 'graph'],
#  ['module'],
#  ['num', 'batch'],
#  ['nones'],
#  ['legacy', 'deconv2d', 'support'],
#  ['Separable', 'Convolution2D'],
#  ['computed', 'tensor'],
#  ['extra', 'ops'],
#  ['model', 'inputs'],
#  ['multiply'],
#  ['indices'],
#  ['non', 'dyn', 'shape'],
#  ['function'],
#  ['layer', 'class', 'name'],
#  ['delete'],
#  ['forward', 'weights'],
#  ['session'],
#  ['ch', 'dim'],
#  ['compute', 'elemwise', 'op', 'output', 'shape'],
#  ['log', 'b', 'next'],
#  ['kernel', 'f'],
#  ['step', 'function'],
#  ['output', 'row'],
#  ['expected', 'output', 'dtype'],
#  ['IMAGE', 'DATA', 'FORMAT'],
#  ['layer', 'config'],
#  ['h', 'tm1'],
#  ['rec', 'dp', 'mask'],
#  ['inputs', 'c'],
#  ['disconnected', 'grad'],
#  ['cell', 'losses'],
#  ['to', 'display'],
#  ['weight', 'values'],
#  ['validation', 'split'],
#  ['callable', 'opts'],
#  ['is', 'chunked'],
#  ['all', 'output', 'shapes'],
#  ['softsign'],
#  ['input', 'names'],
#  ['flatten'],
#  ['neg'],
#  ['num', 'train', 'samples'],
#  ['actual', 'output', 'shape'],
#  ['sample', 'size'],
#  ['axes'],
#  ['step'],
#  ['chunk', 'size'],
#  ['default', 'batch', 'axis'],
#  ['model'],
#  ['min', 'value'],
#  ['decrement'],
#  ['min', 'max', 'norm'],
#  ['target', 'devices'],
#  ['f', 'active', 'next'],
#  ['map', 'fn'],
#  ['check', 'array', 'lengths'],
#  ['get', 'shape'],
#  ['targets'],
#  ['Ones'],
#  ['VAR', 'KEYWORD'],
#  ['predict', 'proba'],
#  ['normalized'],
#  ['final', 'output'],
#  ['inner', 'mask'],
#  ['p', 'list'],
#  ['collected', 'trainable', 'weights'],
#  ['splice'],
#  ['nodes', 'in', 'decreasing', 'depth'],
#  ['get', 'initial', 'state'],
#  ['legacy', 'conv1d', 'support'],
#  ['update', 'func'],
#  ['dense', 'shape'],
#  ['unknown'],
#  ['object', 'name'],
#  ['cudnn', 'gru'],
#  ['writeheader'],
#  ['load', 'weights', 'from', 'hdf5', 'group', 'by', 'name'],
#  ['atrous', 'conv2d', 'transpose'],
#  ['get', 'executor', 'init'],
#  ['recurrent', 'kernel', 'z'],
#  ['output', 'mask', 'cache'],
#  ['x', 'elem'],
#  ['bias', 'add'],
#  ['run', 'thread'],
#  ['active', 'next'],
#  ['Tensor', 'Type'],
#  ['expects', 'training', 'arg'],
#  ['MAX', 'POOLING'],
#  ['else', 'expression'],
#  ['new', 'p'],
#  ['prefix'],
#  ['converted', 'kernel'],
#  ['stdout'],
#  ['untar'],
#  ['Module'],
#  ['Interactive'],
#  ['Expression'],
#  ['Suite'],
#  ['Function', 'Def'],
#  ['Async', 'Function', 'Def'],
#  ['Class', 'Def'],
#  ['Return'],
#  ['Delete'],
#  ['Assign'],
#  ['Aug', 'Assign'],
#  ['For'],
#  ['Async', 'For'],
#  ['While'],
#  ['If'],
#  ['With'],
#  ['Async', 'With'],
#  ['Raise'],
#  ['Try'],
#  ['Assert'],
#  ['Import'],
#  ['Import', 'From'],
#  ['Global'],
#  ['Nonlocal'],
#  ['Expr'],
#  ['Pass'],
#  ['Break'],
#  ['Continue'],
#  ['Bool', 'Op'],
#  ['Bin', 'Op'],
#  ['Unary', 'Op'],
#  ['Lambda'],
#  ['If', 'Exp'],
#  ['Dict'],
#  ['Set'],
#  ['List', 'Comp'],
#  ['Set', 'Comp'],
#  ['Dict', 'Comp'],
#  ['Generator', 'Exp'],
#  ['Await'],
#  ['Yield'],
#  ['Yield', 'From'],
#  ['Compare'],
#  ['Call'],
#  ['Num'],
#  ['Str'],
#  ['Formatted', 'Value'],
#  ['Joined', 'Str'],
#  ['Bytes'],
#  ['Name', 'Constant'],
#  ['Ellipsis'],
#  ['Constant'],
#  ['Attribute'],
#  ['Subscript'],
#  ['Starred'],
#  ['Name'],
#  ['List'],
#  ['Tuple'],
#  ['Load'],
#  ['Store'],
#  ['Del'],
#  ['Aug', 'Load'],
#  ['Aug', 'Store'],
#  ['Param'],
#  ['Slice'],
#  ['Ext', 'Slice'],
#  ['Index'],
#  ['And'],
#  ['Or'],
#  ['Add'],
#  ['Sub'],
#  ['Mult'],
#  ['Mat', 'Mult'],
#  ['Div'],
#  ['Mod'],
#  ['Pow'],
#  ['L', 'Shift'],
#  ['R', 'Shift'],
#  ['Bit', 'Or'],
#  ['Bit', 'Xor'],
#  ['Bit', 'And'],
#  ['Floor', 'Div'],
#  ['Invert'],
#  ['Not'],
#  ['U', 'Add'],
#  ['U', 'Sub'],
#  ['Eq'],
#  ['Not', 'Eq'],
#  ['Lt'],
#  ['Lt', 'E'],
#  ['Gt'],
#  ['Gt', 'E'],
#  ['Is'],
#  ['Is', 'Not'],
#  ['In'],
#  ['Not', 'In'],
#  ['excepthandler'],
#  ['Except', 'Handler'],
#  ['arguments'],
#  ['arg'],
#  ['keyword'],
#  ['alias'],
#  ['withitem'],
#  ['comprehension'],
#  ['[MASK]'],
#  ['[END]'],
#  ['[UNK]']]

# %%
flat_vocab = [y for x in s_vocab for y in x]

# %%
flat_vocab[-2]
# Out:
# '[END]'

# %%
unique_vocab = list(set(flat_vocab))

# %%
vocab_size = len(set(flat_vocab))

# %%
vocab_size
# Out:
# 1413

# %%
s_vocab
# Out:
# [['recurrent', 'dropout', 'mask'],
#  ['output', 'mask'],
#  ['recurrent', 'constraint'],
#  ['string'],
#  ['rmtree'],
#  ['SEQUENCE', 'COUNTER'],
#  ['moving', 'mean'],
#  ['numdigits'],
#  ['cpu', 'merge'],
#  ['module', 'objects'],
#  ['first', 'layer'],
#  ['node'],
#  ['element', 'select'],
#  ['avg'],
#  ['yt'],
#  ['metrics'],
#  ['total', 'size'],
#  ['batch', 'array'],
#  ['directory'],
#  ['n'],
#  ['original', 'node', 'index'],
#  ['rnn'],
#  ['param', 'values'],
#  ['stride', 'd'],
#  ['hsplit'],
#  ['cell', 'contents'],
#  ['input', 'h'],
#  ['separable', 'conv2d'],
#  ['cols'],
#  ['tensor', 'shape'],
#  ['tensor', 'connection'],
#  ['cuda'],
#  ['model', 'weights', 'group'],
#  ['state', 'updates'],
#  ['seen'],
#  ['legacy', 'zeropadding2d', 'support'],
#  ['x', 'aggregate'],
#  ['u'],
#  ['block', 'size'],
#  ['shared'],
#  ['cache', 'dir'],
#  ['Timeseries', 'Generator'],
#  ['download'],
#  ['b', 'carry'],
#  ['inbound', 'names'],
#  ['slice', 'row'],
#  ['sparse', 'tensor', 'to', 'dense'],
#  ['subset'],
#  ['open'],
#  ['max', 'pool3d'],
#  ['sha256'],
#  ['transpose'],
#  ['session', 'kwargs'],
#  ['on', 'train', 'begin'],
#  ['inner', 'input', 'shape'],
#  ['successive', 'outputs'],
#  ['W', 'constraint'],
#  ['not', 'full'],
#  ['where'],
#  ['depthwise', 'conv2d'],
#  ['input'],
#  ['Variable'],
#  ['mask', 'shape'],
#  ['Pool'],
#  ['std'],
#  ['csv', 'file'],
#  ['assign', 'sub'],
#  ['t'],
#  ['second', 'log'],
#  ['depthwise', 'initializer'],
#  ['output', 'generator'],
#  ['gpu', 'id'],
#  ['AVG', 'POOLING'],
#  ['h', 'f'],
#  ['labels', 'train'],
#  ['set'],
#  ['recurrent', 'r'],
#  ['root', 'gradients'],
#  ['tmp', 'target', 'tensors'],
#  ['legacy', 'conv3d', 'support'],
#  ['concatenate'],
#  ['dense', 'mask'],
#  ['stateful', 'metric', 'functions'],
#  ['closure'],
#  ['d', 'decoded'],
#  ['repeat'],
#  ['Global', 'Avg', 'Pool2D'],
#  ['batch', 'set', 'value'],
#  ['norms'],
#  ['split', 'at'],
#  ['z0'],
#  ['sharedvar'],
#  ['height', 'factor'],
#  ['active'],
#  ['opt'],
#  ['bias', 'i', 'i'],
#  ['get', 'default', 'graph'],
#  ['output', 'size'],
#  ['explicitly', 'on', 'cpu'],
#  ['read'],
#  ['value', 'conversions'],
#  ['predict', 'on', 'batch'],
#  ['input'],
#  ['alpha'],
#  ['arrays'],
#  ['tf', 'dtype'],
#  ['add', 'inbound', 'node'],
#  ['datadir', 'base'],
#  ['y', 'pred'],
#  ['verbose'],
#  ['common', 'factor'],
#  ['left', 'pad'],
#  ['slice', 'length'],
#  ['output', 'layers'],
#  ['mask'],
#  ['batch', 'count'],
#  ['ones'],
#  ['normalize', 'batch', 'in', 'training'],
#  ['layer', 'weights'],
#  ['alpha', 'initializer'],
#  ['gamma', 'constraint'],
#  ['dim2', 'cropping'],
#  ['build'],
#  ['Xception'],
#  ['depthwise', 'constraint'],
#  ['cond', 'shape'],
#  ['assign', 'embeddings'],
#  ['broadcast', 'moving', 'mean'],
#  ['set', 'global', 'option'],
#  ['h', 'tm1', 'h'],
#  ['W'],
#  ['svd'],
#  ['rescale'],
#  ['full', 'input', 'spec'],
#  ['weights'],
#  ['broadcast', 'as'],
#  ['full', 'input'],
#  ['num', 'words'],
#  ['rnn', 'layer'],
#  ['batch', 'axis'],
#  ['sublayer'],
#  ['input', 'layer'],
#  ['when'],
#  ['layers', 'with', 'complete', 'input'],
#  ['uses', 'learning', 'phase'],
#  ['queue'],
#  ['exceptions'],
#  ['fn'],
#  ['batch', 'normalization', 'test'],
#  ['arg', 'dict'],
#  ['is', 'placeholder'],
#  ['new', 'dim'],
#  ['layer', 'group'],
#  ['Inferred', 'Dimension'],
#  ['loss', 'weight'],
#  ['args'],
#  ['version'],
#  ['th', 'padding'],
#  ['mode'],
#  ['legacy', 'spatialdropout', 'Nd', 'support'],
#  ['convert', 'to', 'tensor'],
#  ['x', 'f'],
#  ['hexdigest'],
#  ['recurrent', 'activation'],
#  ['nodes', 'depths'],
#  ['state', 'size'],
#  ['stateful', 'metrics'],
#  ['greater'],
#  ['Cudnn', 'LSTM'],
#  ['get', 'uid'],
#  ['kernel', 'initializer'],
#  ['grads'],
#  ['simple', 'value'],
#  ['new', 'd', 'a'],
#  ['slice', 'i'],
#  ['default', 'options'],
#  ['call'],
#  ['kernel', 'i'],
#  ['target', 'dim'],
#  ['less'],
#  [],
#  ['state', 'spec'],
#  ['mask', 'slice'],
#  ['pointwise', 'initializer'],
#  ['hh'],
#  ['embedding', 'input'],
#  ['cntk', 'shape'],
#  ['zero'],
#  ['m', 'schedule', 'next'],
#  ['weight', 'type'],
#  ['pool', '3d'],
#  ['line', 'length'],
#  ['recurrent', 'bias', 'z'],
#  ['save', 'weights', 'only'],
#  ['tile', 'shape'],
#  ['version'],
#  ['xm'],
#  ['phase'],
#  ['compute', 'mask'],
#  ['f', 'stats'],
#  ['one'],
#  ['write', 'grads'],
#  ['output', 'dim'],
#  ['non', 'trainable', 'weights'],
#  ['test', 'function'],
#  ['Summary'],
#  ['integer'],
#  ['embeddings'],
#  ['preprocessing', 'function'],
#  ['cval'],
#  ['save', 'img'],
#  ['skip', 'idxs'],
#  ['softmax'],
#  ['output', 'dimensions'],
#  ['postfix', 'shape'],
#  ['vertical', 'flip'],
#  ['states'],
#  ['delta', 't', 'batch'],
#  ['mask', 't'],
#  ['batch', 'input', 'shape'],
#  ['batch', 'size'],
#  ['s'],
#  ['predict'],
#  ['rnn', 'inputs'],
#  ['pointwise', 'constraint'],
#  ['val', 'x'],
#  ['restore', 'best', 'weights'],
#  ['beta', 'constraint'],
#  ['generator'],
#  ['output'],
#  ['image', 'data', 'format'],
#  ['val', 'sample', 'weight'],
#  ['metadata', 'path'],
#  ['replace', 'placeholders'],
#  ['cropping', 'all', 'dims'],
#  ['GLOBAL', 'CUSTOM', 'OBJECTS'],
#  ['axis', 'without', 'batch'],
#  ['batch', 'logs'],
#  ['fit'],
#  ['width', 'padding'],
#  ['batch', 'start'],
#  ['deconv', 'length'],
#  ['shape1'],
#  ['list', 'devices'],
#  ['channel', 'shift', 'range'],
#  ['make', 'callable', 'from', 'options'],
#  ['elems'],
#  ['allowed', 'positional', 'args'],
#  ['fields'],
#  ['placeholder', 'with', 'default'],
#  ['smoothed', 'predict'],
#  ['tanh'],
#  ['count', 'mode'],
#  ['filename'],
#  ['trainer', 'output'],
#  ['max', 'num', 'labels', 'tns'],
#  ['totals'],
#  ['spatial', '2d', 'padding'],
#  ['batch', 'get', 'value'],
#  ['min', 'delta'],
#  ['POSITIONAL', 'OR', 'KEYWORD'],
#  ['cpu', 'relocation'],
#  ['varkw'],
#  ['ctc', 'loss'],
#  ['Deconvolution3D'],
#  ['kernel', 'size'],
#  ['adj', 'x'],
#  ['const', 'a'],
#  ['unroll'],
#  ['swapaxes'],
#  ['dilation'],
#  ['featurewise', 'center'],
#  ['original', 'input', 'spec'],
#  ['initial', 'states'],
#  ['gradients'],
#  ['normalize'],
#  ['stateful', 'metric', 'names'],
#  ['name'],
#  ['default'],
#  ['SHARED', 'SEQUENCES'],
#  ['ndim', 'cond'],
#  ['Tensor', 'Like'],
#  ['sleep'],
#  ['zca', 'whitening'],
#  ['requests'],
#  ['mask', 'i'],
#  ['legacy', 'lambda', 'support'],
#  ['regularization'],
#  ['hash', 'algorithm'],
#  ['current'],
#  ['wait', 'time'],
#  ['access'],
#  ['EPSILON'],
#  ['allowed', 'kwargs'],
#  ['structured', 'dot'],
#  ['Optimizer'],
#  ['noise', 'shape'],
#  ['legacy', 'pooling2d', 'support'],
#  ['candidate', 'vars'],
#  ['axis'],
#  ['max', 'queue', 'size'],
#  ['predict', 'function'],
#  ['legal', 'params', 'fns'],
#  ['pad'],
#  ['input', 'ndims'],
#  ['input', 'shape'],
#  ['inputs', 'r'],
#  ['kept', 'idx'],
#  ['init', 'graph', 'network'],
#  ['skip', 'mismatch'],
#  ['save'],
#  ['averages'],
#  ['learning', 'phase'],
#  ['tolist'],
#  ['d'],
#  ['beta', '1'],
#  ['unpickle', 'model'],
#  ['ctc', 'beam', 'search', 'decoder'],
#  ['condition'],
#  ['set', 'value'],
#  ['y', 'test'],
#  ['feed'],
#  ['loss'],
#  ['resize', 'nearest', 'neighbor'],
#  ['go', 'backwards'],
#  ['uses', 'lp'],
#  ['start', 'char'],
#  ['constants'],
#  ['train', 'on', 'batch'],
#  ['spatial', 'axes'],
#  ['clipvalue'],
#  ['skip', 'target', 'indices'],
#  ['layer', 'output', 'tensors'],
#  ['inc', 'subtensor'],
#  ['logits'],
#  ['dense'],
#  ['expand', 'dims'],
#  ['Edge'],
#  ['delta', 't', 'median'],
#  ['initial', 'weights'],
#  ['var'],
#  ['gens'],
#  ['SESSION'],
#  ['else', 'expression', 'fn'],
#  ['zeros'],
#  ['unit', 'forget', 'bias'],
#  ['converted'],
#  ['get'],
#  ['output', 'metrics'],
#  ['batch', 'shape'],
#  ['h', 'o'],
#  ['function', 'type'],
#  ['mutex'],
#  ['axes'],
#  ['input', 'length', 'step'],
#  ['u'],
#  ['computed', 'masks'],
#  ['xt'],
#  ['history'],
#  ['array', 'to', 'img'],
#  ['uint8'],
#  ['cond', 'ndim'],
#  ['log', 'b', 'probs'],
#  ['forward'],
#  ['samples'],
#  ['z1'],
#  ['Global', 'Max', 'Pool3D'],
#  ['sparse', 'categorical', 'crossentropy'],
#  ['get', 'value'],
#  ['feed', 'output', 'names'],
#  ['binomial'],
#  ['tensor', 'index'],
#  ['normalize', 'data', 'format'],
#  ['create', 'dataset'],
#  ['w', 'pad'],
#  ['legacy', 'call'],
#  ['load', 'weights', 'from', 'hdf5', 'group'],
#  ['loss', 'name'],
#  ['adamax'],
#  ['unpack'],
#  ['layer', 'data'],
#  ['inputs', 'z'],
#  ['dim', 'ordering'],
#  ['moments'],
#  ['vhat', 't'],
#  ['image', 'data', 'generator'],
#  ['kernel', 'w'],
#  ['h5py'],
#  ['visualize', 'embeddings'],
#  ['inbound', 'tensor', 'index'],
#  ['val', 'enqueuer'],
#  ['file'],
#  ['kwd'],
#  ['floatx'],
#  ['median'],
#  ['forward', 'losses'],
#  ['new', 'layer'],
#  ['col'],
#  ['output', 'values'],
#  ['parts'],
#  ['vhat'],
#  ['file', 'path'],
#  ['layer', 'weights', 'shape'],
#  ['prod'],
#  ['tensor', 'indices'],
#  ['y', 'true'],
#  ['get', 'session'],
#  ['cond'],
#  ['py', 'any'],
#  ['progbar'],
#  ['Inf'],
#  ['backward', 'state'],
#  ['regularizer'],
#  ['num', 'test'],
#  ['n', 'classes'],
#  ['device', 'type'],
#  ['concat'],
#  ['temporal', 'padding'],
#  ['csr', 'matrix'],
#  ['tuples'],
#  ['callback'],
#  ['Progbar', 'Logger'],
#  ['bad', 'attributes'],
#  ['instance'],
#  ['Tensor', 'Variable'],
#  ['Constant'],
#  ['co', 'name'],
#  ['use', 'multiprocessing'],
#  ['reset', 'after'],
#  ['get', 'layer'],
#  ['gather', 'nd'],
#  ['input', 'dtype'],
#  ['barstr'],
#  ['add', 'loss'],
#  ['max', 'norm'],
#  ['output', 'keras', 'shape'],
#  ['filters'],
#  ['reverse', 'state', 'order'],
#  ['feed', 'loss', 'fns'],
#  ['unconcatenated', 'outs'],
#  ['out', 'filters'],
#  ['right', 'pad'],
#  ['assign', 'add'],
#  ['old', 'name'],
#  ['normalized', 'axis'],
#  ['on', 'epoch', 'begin'],
#  ['previous', 'feature', 'map', 'shape'],
#  ['Dense', 'Net201'],
#  ['oh'],
#  ['avg', 'pool'],
#  ['generator', 'output'],
#  ['predict', 'loop'],
#  ['Tensor', 'Shared', 'Variable'],
#  ['depth', 'multiplier'],
#  ['recurrent', 'h'],
#  ['end', 'index'],
#  ['recurrent', 'kernel', 'h'],
#  ['targets', 'values'],
#  ['actual', 'dim'],
#  ['initializer'],
#  ['all', 'classes'],
#  ['weighted', 'losses'],
#  ['height', 'cropping'],
#  ['h', 'tm1', 'r'],
#  ['sum'],
#  ['isinf'],
#  ['negative', 'slope'],
#  ['bias', 'c'],
#  ['num', 'old', 'batch'],
#  ['output', 'shape'],
#  ['finished', 'nodes'],
#  ['newly', 'created', 'input', 'layer'],
#  ['identity'],
#  ['num', 'dynamic'],
#  ['states', 'at', 'step'],
#  ['predict', 'classes'],
#  ['dynamic', 'axis', 'index'],
#  ['bilinear', 'upsampling'],
#  ['imgpath'],
#  ['allow', 'tuple'],
#  ['momentum', 'cache', 't'],
#  ['keras', 'shape'],
#  ['epsilon'],
#  ['set', 'subtensor'],
#  ['find', 'all', 'with', 'name'],
#  ['cell', 'config'],
#  ['metric', 'name'],
#  ['keras', 'shape'],
#  ['non', 'trainable', 'weights'],
#  ['Global', 'Avg', 'Pool3D'],
#  ['inner', 'inputs'],
#  ['maxlen'],
#  ['hard', 'sigmoid'],
#  ['num', 'states'],
#  ['first', 'connection'],
#  ['constraints'],
#  ['legacy', 'separable', 'conv2d', 'support'],
#  ['chunk'],
#  ['bn'],
#  ['W', 'OK'],
#  ['out', 'labels'],
#  ['g'],
#  ['Global', 'Avg', 'Pool1D'],
#  ['h'],
#  ['output', 'ta', 't'],
#  ['orthogonal'],
#  ['Node'],
#  ['batch', 'normalization'],
#  ['element', 'min'],
#  ['t', 'enter', 'batch'],
#  ['line'],
#  ['min', 'lr'],
#  ['matmul'],
#  ['slice'],
#  ['kwargs'],
#  ['network', 'nodes'],
#  ['log', 'dir'],
#  ['original', 'fm', 'shape'],
#  ['bias', 'o', 'i'],
#  ['connections'],
#  ['tocoo'],
#  ['legacy', 'dense', 'support'],
#  ['Dense', 'Net121'],
#  ['samples', 'seen', 'at', 'last', 'write'],
#  ['get', 'monitor', 'value'],
#  ['weighted', 'loss'],
#  ['resize', 'bilinear'],
#  ['feed', 'output', 'names'],
#  ['extract'],
#  ['deserialized'],
#  ['backward', 'weights'],
#  ['inbound', 'layer', 'id'],
#  ['legacy', 'convlstm2d', 'support'],
#  ['open', 'args'],
#  ['reshape'],
#  ['rho'],
#  ['fit', 'args'],
#  ['assign', 'op'],
#  ['num', 'chunks'],
#  ['delta', 'ts', 'batch', 'end'],
#  ['endswith'],
#  ['output', 'tensors'],
#  ['extractall'],
#  ['vstack'],
#  ['v', 't', 'prime'],
#  ['use', 'bias'],
#  ['Free', 'Dimension'],
#  ['random', 'seed'],
#  ['batch'],
#  ['Directory', 'Iterator'],
#  ['input', 'length'],
#  ['stateful', 'metric', 'indices'],
#  ['layer', 'id'],
#  ['loss', 'function'],
#  ['new', 'keywords'],
#  ['min', 'ndim'],
#  ['format'],
#  ['new', 'values'],
#  ['preprocessor'],
#  ['opt', 'update'],
#  ['fpath', 'file'],
#  ['fetches'],
#  ['dim1', 'cropping'],
#  ['recurrent', 'dropout'],
#  ['py', 'all'],
#  ['inp'],
#  ['out', 'pad'],
#  ['nodes', 'by', 'depth'],
#  ['unique', 'tensors'],
#  ['legacy', 'embedding', 'support'],
#  ['callbacks'],
#  ['inputs', 'f'],
#  ['square', 'sum'],
#  ['is', 'graph', 'network'],
#  ['clip'],
#  ['param', 'dset'],
#  ['data', 'npy'],
#  ['steps', 'done'],
#  ['unique', 'name'],
#  ['num', 'element'],
#  ['logs'],
#  ['broadcast', 'moving', 'variance'],
#  ['time'],
#  ['workers'],
#  ['trainable'],
#  ['proba'],
#  ['separable', 'conv1d'],
#  ['idxs'],
#  ['qsize'],
#  ['compute', 'output', 'shape'],
#  ['L1L2'],
#  ['out', 'dim'],
#  ['space'],
#  ['Event'],
#  ['order'],
#  ['feed', 'symbols'],
#  ['Method', 'Type'],
#  ['pointwise', 'kernel', 'shape'],
#  ['text', 'to', 'word', 'sequence'],
#  ['loads'],
#  ['n', 's'],
#  ['hasher'],
#  ['random', 'normal', 'initializer'],
#  ['input', 'uid'],
#  ['reference', 'input', 'tensors'],
#  ['lower'],
#  ['updates'],
#  ['post'],
#  ['wait', 'queue'],
#  ['foldr'],
#  ['optimizer', 'config'],
#  ['dynamic', 'display'],
#  ['inputs', 'i'],
#  ['step', 'index'],
#  ['xs'],
#  ['standardize', 'args'],
#  ['expr', 'ndim'],
#  ['training', 'updates'],
#  ['to', 'sequence'],
#  ['square'],
#  ['mapped', 'weight', 'name'],
#  ['new', 'output'],
#  ['all', 'outs'],
#  ['inf'],
#  ['kernels'],
#  ['Sparse', 'Type'],
#  ['i', 's'],
#  ['searchsorted'],
#  ['label'],
#  ['archive', 'format'],
#  ['symbolic', 'shape'],
#  ['targets'],
#  ['legacy', 'model', 'constructor', 'support'],
#  ['out', 'pad', 'h'],
#  ['MAE'],
#  ['File'],
#  ['outputs'],
#  ['py', 'slice'],
#  ['ndim', 'diff'],
#  ['original', 'input', 'layer'],
#  ['NAS', 'Net', 'Mobile'],
#  ['normalizer'],
#  ['stddev'],
#  ['MAPE'],
#  ['NAME', 'SCOPE', 'STACK'],
#  ['mape'],
#  ['act'],
#  ['dnn', 'batch', 'normalization', 'train'],
#  ['slices', 'dims'],
#  ['get', 'updates'],
#  ['schedule', 'decay'],
#  ['legacy', 'conv2d', 'support'],
#  ['new', 'a'],
#  ['url'],
#  ['c', 'tm1'],
#  ['mean'],
#  ['eye'],
#  ['ge'],
#  ['Deconv2D'],
#  ['gamma'],
#  ['nv'],
#  ['prog', 'width'],
#  ['preds'],
#  ['array'],
#  ['legacy', 'upsampling1d', 'support'],
#  ['time', 'per', 'unit'],
#  ['s1'],
#  ['recurrent', 'bias', 'h'],
#  ['u', 't'],
#  ['add', 'weight'],
#  ['reference', 'output', 'tensors'],
#  ['computed', 'mask'],
#  ['param'],
#  ['skip', 'top'],
#  ['label', 'shape'],
#  ['val', 'gen'],
#  ['batch', 'end'],
#  ['no', 'flip'],
#  ['errno'],
#  ['feed', 'input', 'names'],
#  ['d', 'pad'],
#  ['categorical'],
#  ['inbound', 'node', 'index'],
#  ['stride', 'row'],
#  ['validation', 'data'],
#  ['alias'],
#  ['HDF5', 'OBJECT', 'HEADER', 'LIMIT'],
#  ['in', 'lens'],
#  ['pointwise', 'kernel'],
#  ['prefix', 'shape'],
#  ['input', 'data', 'shape'],
#  ['to', 'int32'],
#  ['inputs', 'h'],
#  ['inbound', 'layer', 'name'],
#  ['name'],
#  ['clipnorm'],
#  ['supports', 'masking'],
#  ['input', 'row'],
#  ['x', 'h'],
#  ['random', 'channel', 'shift'],
#  ['generate', 'legacy', 'method', 'interface'],
#  ['shuffle'],
#  ['get', 'lock'],
#  ['v', 't'],
#  ['alpha', 'regularizer'],
#  ['computed', 'data'],
#  ['cudnn', 'lstm'],
#  ['recurrent', 'bias', 'r'],
#  ['layer', 'indices'],
#  ['spatial', '3d', 'padding'],
#  ['archive', 'type'],
#  ['cropping'],
#  ['VGG16'],
#  ['output', 'slice'],
#  ['weight', 'value', 'tuples'],
#  ['epoch'],
#  ['batch', 'id'],
#  ['origin'],
#  ['theta'],
#  ['cross', 'entropy', 'with', 'softmax'],
#  ['array', 'vals'],
#  ['input', 'layers'],
#  ['copy'],
#  ['type'],
#  ['nested', 'states'],
#  ['dtype'],
#  ['moving', 'average', 'update'],
#  ['Print'],
#  ['asarray'],
#  ['function', 'name'],
#  ['legacy', 'cropping2d', 'support'],
#  ['environ'],
#  ['epsilon'],
#  ['x', 'test'],
#  ['zca', 'epsilon'],
#  ['chunk', 'id'],
#  ['sparse', 'placeholder'],
#  ['f'],
#  ['evaluate', 'generator'],
#  ['time', 'steps'],
#  ['new', 'c'],
#  ['legacy', 'spatialdropout1d', 'support'],
#  ['op'],
#  ['local', 'conv1d'],
#  ['base', 'dtype'],
#  ['previous', 'sources'],
#  ['argmax'],
#  ['layers', 'to', 'output', 'shapes'],
#  ['y', 'loc'],
#  ['input', 'list'],
#  ['recurrent', 'conv'],
#  ['Tar', 'Error'],
#  ['relu'],
#  ['moving', 'mean', 'initializer'],
#  ['uninitialized', 'vars'],
#  ['History'],
#  ['broadcast'],
#  ['send', 'sequence'],
#  ['then', 'expression', 'fn'],
#  ['results'],
#  ['le'],
#  ['value', 'tuple'],
#  ['l2'],
#  ['switch'],
#  ['float', 'X'],
#  ['m', 'schedule', 'new'],
#  ['val', 'y'],
#  ['value'],
#  ['times'],
#  ['pool3d'],
#  ['intermediate'],
#  ['stop', 'training'],
#  ['Deconvolution2D'],
#  ['relu6'],
#  ['key'],
#  ['initial', 'state'],
#  ['squeeze'],
#  ['output', 'coordinates'],
#  ['update', 'freq'],
#  ['hstack'],
#  ['output', 'shape'],
#  ['num', 'constants'],
#  ['stride', 'h'],
#  ['shape', 'key'],
#  ['dynamic', 'axes'],
#  ['reporthook'],
#  ['send', 'as', 'json'],
#  ['stop', 'signal'],
#  ['variables'],
#  ['high'],
#  ['int32'],
#  ['equal'],
#  ['File', 'Writer'],
#  ['width'],
#  ['out', 'depth'],
#  ['normal', 't'],
#  ['score', 'array'],
#  ['transform', 'weight'],
#  ['Callable', 'Options'],
#  ['frombuffer'],
#  ['Config', 'Proto'],
#  ['timesteps'],
#  ['to', 'file'],
#  ['generic'],
#  ['image'],
#  ['fname'],
#  ['embedding', 'lookup'],
#  ['categorical', 'crossentropy'],
#  ['assign', 'placeholder'],
#  ['cntk', 'placeholder'],
#  ['min'],
#  ['weighted', 'metric', 'fn'],
#  ['getfullargspec'],
#  ['to', 'sequence', 'like'],
#  ['empty'],
#  ['set', 'inputs'],
#  ['bias', 'z'],
#  ['output', 'masks'],
#  ['conv1d'],
#  ['states'],
#  ['max', 'ndim'],
#  ['increment'],
#  ['start', 'idx'],
#  ['dilation', 'rate'],
#  ['weight'],
#  ['element', 'max'],
#  ['log10'],
#  ['t', 'before', 'callbacks'],
#  ['path'],
#  ['Tensor', 'Array'],
#  ['log', 'first'],
#  ['merge', 'mode'],
#  ['positions'],
#  ['rep'],
#  ['Thread'],
#  ['cls', 'name'],
#  ['types'],
#  ['node', 'data'],
#  ['labels', 'test'],
#  ['auxiliary', 'axis'],
#  ['forward', 'layer'],
#  ['rate'],
#  ['first', 'log'],
#  ['m', 't', 'bar'],
#  ['timeout'],
#  ['last', 'states'],
#  ['embedding'],
#  ['known'],
#  ['GRAPH', 'UID', 'DICTS'],
#  ['input', 'index'],
#  ['embeddings', 'data'],
#  ['step', 'input', 'shape'],
#  ['argmin'],
#  ['img'],
#  ['task', 'done'],
#  ['x', 'flatten'],
#  ['target', 'size'],
#  ['constraint'],
#  ['old', 'value'],
#  ['fixed', 'batch', 'size'],
#  ['decay'],
#  ['mask', 'ta'],
#  ['printable', 'module', 'name'],
#  ['base', 'shape'],
#  ['callable', 'fn'],
#  ['feed', 'input', 'shapes'],
#  ['merge', 'all'],
#  ['range'],
#  ['embedding', 'size'],
#  ['convolution', 'transpose'],
#  ['predictions'],
#  ['biases'],
#  ['save', 'weights', 'to', 'hdf5', 'group'],
#  ['broadcast', 'gamma'],
#  ['Global', 'Max', 'Pool2D'],
#  ['sigmoid'],
#  ['replace'],
#  ['p'],
#  ['dropout', 'mask'],
#  ['limit'],
#  ['stateful'],
#  ['sub'],
#  ['dense', 'shape'],
#  ['learner'],
#  ['model', 'outputs'],
#  ['optimizer'],
#  ['pooling', 'function'],
#  ['forward', 'updates'],
#  ['regularization', 'loss'],
#  ['Abstract', 'Conv3d', 'grad', 'Inputs'],
#  ['updates', 'ops'],
#  ['recurrent', 'kernel'],
#  ['metric', 'result'],
#  ['to', 'tensor'],
#  ['recurrent', 'regularizer'],
#  ['lt'],
#  ['f', 'active'],
#  ['n', 'samples'],
#  ['previous', 'depth'],
#  ['get', 'losses', 'for'],
#  ['shared', 'axes'],
#  ['legacy', 'zeropadding3d', 'support'],
#  ['combine'],
#  ['Y'],
#  ['keys'],
#  ['build', 'input', 'shape'],
#  ['samples', 'seen', 'since'],
#  ['device'],
#  ['make', 'sampling', 'table'],
#  ['root'],
#  ['output', 'tensor'],
#  ['summary', 'value'],
#  ['Ordered', 'Dict'],
#  ['reduction', 'axes'],
#  ['filter', 'sk', 'params'],
#  ['isnan'],
#  ['file', 'flags'],
#  ['layers', 'for', 'depth'],
#  ['dim3', 'cropping'],
#  ['ident'],
#  ['model', 'layers'],
#  ['flat', 'shape'],
#  ['print', 'fn'],
#  ['val', 'data'],
#  ['variables', 'initializer'],
#  ['callback', 'metrics'],
#  ['batch', 'ind'],
#  ['by', 'name'],
#  ['delta', 'accumulators'],
#  ['isfile'],
#  ['assign'],
#  ['j'],
#  ['th', 'sparse', 'module'],
#  ['new', 'arg'],
#  ['save', 'to', 'dir'],
#  ['child', 'class', 'name'],
#  ['new', 'width'],
#  ['symbol', 'vals'],
#  ['kernel', 'c'],
#  ['successive', 'states'],
#  ['abs'],
#  ['temp'],
#  ['random', 'uniform', 'initializer'],
#  ['bias', 'f'],
#  ['nbytes'],
#  ['string', 'types'],
#  ['trainable', 'count'],
#  ['feature', 'dim'],
#  ['init', 'subclassed', 'network'],
#  ['values'],
#  ['moves'],
#  ['chunk', 'attr'],
#  ['ki'],
#  ['metrics', 'updates'],
#  ['run'],
#  ['group'],
#  ['total', 'log', 'prob'],
#  ['in', 'cooldown'],
#  ['out'],
#  ['rmsprop'],
#  ['not', 'equal'],
#  ['LEARNING', 'PHASE'],
#  ['tensor'],
#  ['init'],
#  ['x', 'o'],
#  ['Numpy', 'Array', 'Iterator'],
#  ['kernel', 'r'],
#  ['fit', 'loop'],
#  ['unit', 'norm'],
#  ['embeddings', 'metadata'],
#  ['x', 'z'],
#  ['cosine'],
#  ['is', 'compiled'],
#  ['set', 'x'],
#  ['get', 'default', 'session'],
#  ['feed', 'inputs'],
#  ['get', 'config'],
#  ['reduce', 'any'],
#  ['num', 'constants'],
#  ['non', 'trainable', 'count'],
#  ['conv2d'],
#  ['ops'],
#  ['py', 'sum'],
#  ['len', 'dim2'],
#  ['reverse'],
#  ['x', 'train'],
#  ['b', 'any'],
#  ['outs', 'per', 'batch'],
#  ['node', 'conversion', 'map'],
#  ['current', 'layout'],
#  ['m', 't', 'prime'],
#  ['output', 'ls', 'copy'],
#  ['Dataset'],
#  ['process', 'batch'],
#  ['len', 'dim1'],
#  ['inbound', 'nodes', 'data'],
#  ['sparse', 'softmax', 'cross', 'entropy', 'with', 'logits'],
#  ['computable', 'tensors'],
#  ['width', 'factor'],
#  ['ctc', 'greedy', 'decoder'],
#  ...]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lencoder = LabelEncoder()

# %%
lencoder.fit_transform(unique_vocab)
# Out:
# array([  45,   27, 1107, ...,  119, 1224, 1331])

# %%
max_len = max([len(v) for v in split_vocab])
max_len
# Out:
# 7

# %%
data = np.zeros((len(s_vocab), max_len), dtype=int)
data.shape
# Out:
# (2505, 7)

# %%
for i, sv in enumerate(s_vocab):
    for j,s in enumerate(sv):
        data[i][j] = lencoder.transform([s])
    while j < max_len:
        data[i][j] = unique_vocab.index('[END]')
        j+=1

# %%
import sys
# !{sys.executable} -m pip install gensim
# Out:
# Requirement already satisfied: gensim in ./py37/lib/python3.7/site-packages (3.6.0)
# Requirement already satisfied: six>=1.5.0 in ./py37/lib/python3.7/site-packages (from gensim) (1.11.0)
# Requirement already satisfied: numpy>=1.11.3 in ./py37/lib/python3.7/site-packages (from gensim) (1.15.4)
# Requirement already satisfied: scipy>=0.18.1 in ./py37/lib/python3.7/site-packages (from gensim) (1.1.0)
# Requirement already satisfied: smart-open>=1.2.1 in ./py37/lib/python3.7/site-packages (from gensim) (1.7.1)
# Requirement already satisfied: boto>=2.32 in ./py37/lib/python3.7/site-packages (from smart-open>=1.2.1->gensim) (2.49.0)
# Requirement already satisfied: boto3 in ./py37/lib/python3.7/site-packages (from smart-open>=1.2.1->gensim) (1.9.69)
# Requirement already satisfied: bz2file in ./py37/lib/python3.7/site-packages (from smart-open>=1.2.1->gensim) (0.98)
# Requirement already satisfied: requests in ./py37/lib/python3.7/site-packages (from smart-open>=1.2.1->gensim) (2.21.0)
# Requirement already satisfied: botocore<1.13.0,>=1.12.69 in ./py37/lib/python3.7/site-packages (from boto3->smart-open>=1.2.1->gensim) (1.12.69)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in ./py37/lib/python3.7/site-packages (from boto3->smart-open>=1.2.1->gensim) (0.9.3)
# Requirement already satisfied: s3transfer<0.2.0,>=0.1.10 in ./py37/lib/python3.7/site-packages (from boto3->smart-open>=1.2.1->gensim) (0.1.13)
# Requirement already satisfied: idna<2.9,>=2.5 in ./py37/lib/python3.7/site-packages (from requests->smart-open>=1.2.1->gensim) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in ./py37/lib/python3.7/site-packages (from requests->smart-open>=1.2.1->gensim) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./py37/lib/python3.7/site-packages (from requests->smart-open>=1.2.1->gensim) (2018.11.29)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in ./py37/lib/python3.7/site-packages (from requests->smart-open>=1.2.1->gensim) (3.0.4)
# Requirement already satisfied: docutils>=0.10 in ./py37/lib/python3.7/site-packages (from botocore<1.13.0,>=1.12.69->boto3->smart-open>=1.2.1->gensim) (0.14)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1; python_version >= "2.7" in ./py37/lib/python3.7/site-packages (from botocore<1.13.0,>=1.12.69->boto3->smart-open>=1.2.1->gensim) (2.7.5)

# %%
import gensim, logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
sentences = s_vocab

# %%
# train word2vec on the two sentences
model = gensim.models.Word2Vec(sentences, window=1, size=64, min_count=0)
# Out:
# 2018-12-19 17:53:58,529 : INFO : collecting all words and their counts
# 2018-12-19 17:53:58,531 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-12-19 17:53:58,538 : INFO : collected 1413 word types from a corpus of 4607 raw words and 2505 sentences
# 2018-12-19 17:53:58,539 : INFO : Loading a fresh vocabulary
# 2018-12-19 17:53:58,548 : INFO : effective_min_count=0 retains 1413 unique words (100% of original 1413, drops 0)
# 2018-12-19 17:53:58,549 : INFO : effective_min_count=0 leaves 4607 word corpus (100% of original 4607, drops 0)
# 2018-12-19 17:53:58,557 : INFO : deleting the raw counts dictionary of 1413 items
# 2018-12-19 17:53:58,559 : INFO : sample=0.001 downsamples 62 most-common words
# 2018-12-19 17:53:58,560 : INFO : downsampling leaves estimated 4086 word corpus (88.7% of prior 4607)
# 2018-12-19 17:53:58,565 : INFO : estimated required memory for 1413 words and 64 dimensions: 1429956 bytes
# 2018-12-19 17:53:58,567 : INFO : resetting layer weights
# 2018-12-19 17:53:58,603 : INFO : training model with 3 workers on 1413 vocabulary and 64 features, using sg=0 hs=0 sample=0.001 negative=5 window=1
# 2018-12-19 17:53:58,616 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-12-19 17:53:58,619 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-12-19 17:53:58,625 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-12-19 17:53:58,627 : INFO : EPOCH - 1 : training on 4607 raw words (4079 effective words) took 0.0s, 378888 effective words/s
# 2018-12-19 17:53:58,640 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-12-19 17:53:58,642 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-12-19 17:53:58,649 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-12-19 17:53:58,650 : INFO : EPOCH - 2 : training on 4607 raw words (4093 effective words) took 0.0s, 274649 effective words/s
# 2018-12-19 17:53:58,664 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-12-19 17:53:58,665 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-12-19 17:53:58,672 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-12-19 17:53:58,673 : INFO : EPOCH - 3 : training on 4607 raw words (4078 effective words) took 0.0s, 291312 effective words/s
# 2018-12-19 17:53:58,684 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-12-19 17:53:58,685 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-12-19 17:53:58,691 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-12-19 17:53:58,692 : INFO : EPOCH - 4 : training on 4607 raw words (4109 effective words) took 0.0s, 361579 effective words/s
# 2018-12-19 17:53:58,706 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-12-19 17:53:58,707 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-12-19 17:53:58,713 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-12-19 17:53:58,714 : INFO : EPOCH - 5 : training on 4607 raw words (4078 effective words) took 0.0s, 423698 effective words/s
# 2018-12-19 17:53:58,715 : INFO : training on a 23035 raw words (20437 effective words) took 0.1s, 183745 effective words/s
# 2018-12-19 17:53:58,716 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
model.similarity('y', 'train')
# Out:
# /dfs/scratch0/dtsbourg/SAGE-fmt/py37/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """Entry point for launching an IPython kernel.
# /dfs/scratch0/dtsbourg/SAGE-fmt/py37/lib/python3.7/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# -0.014980327

# %%
model.save("token2vec.model")
# Out:
# 2018-12-19 17:54:01,364 : INFO : saving Word2Vec object under token2vec.model, separately None
# 2018-12-19 17:54:01,365 : INFO : not storing attribute vectors_norm
# 2018-12-19 17:54:01,367 : INFO : not storing attribute cum_table
# 2018-12-19 17:54:01,444 : INFO : saved token2vec.model

# %%
varname = "x_trainNet"

# %%
subtoks = flatten([camel_case_split(v) for v in varname.split('_')])

# %%
np.mean([model[sk] for sk in subtoks], axis=0).shape
# Out:
# /dfs/scratch0/dtsbourg/SAGE-fmt/py37/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# (64,)
